# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Импорт-данных" data-toc-modified-id="Импорт-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Импорт данных</a></span></li><li><span><a href="#Изучение-общей-информации" data-toc-modified-id="Изучение-общей-информации-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Изучение общей информации</a></span><ul class="toc-item"><li><span><a href="#Изучим-таблицу-visits." data-toc-modified-id="Изучим-таблицу-visits.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Изучим таблицу <code>visits</code>.</a></span></li><li><span><a href="#Изучим-таблицу-orders." data-toc-modified-id="Изучим-таблицу-orders.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Изучим таблицу <code>orders</code>.</a></span></li><li><span><a href="#Изучим-таблицу-costs." data-toc-modified-id="Изучим-таблицу-costs.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Изучим таблицу <code>costs</code>.</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Стиль-заголовков" data-toc-modified-id="Стиль-заголовков-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Стиль заголовков</a></span></li><li><span><a href="#Изменение-типов-данных" data-toc-modified-id="Изменение-типов-данных-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Изменение типов данных</a></span></li><li><span><a href="#Дубликаты" data-toc-modified-id="Дубликаты-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Дубликаты</a></span></li></ul></li><li><span><a href="#Задайте-функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Задайте-функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Задайте функции для расчета и анализа LTV, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Функция-для-создания-пользовательских-профилей" data-toc-modified-id="Функция-для-создания-пользовательских-профилей-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Функция для создания пользовательских профилей</a></span></li><li><span><a href="#Функция-для-расчёта-LTV-и-ROI" data-toc-modified-id="Функция-для-расчёта-LTV-и-ROI-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Функция для расчёта LTV и ROI</a></span></li><li><span><a href="#Функция-для-расчёта-удержания" data-toc-modified-id="Функция-для-расчёта-удержания-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Функция для расчёта удержания</a></span></li><li><span><a href="#Функция-для-расчёта-конверсии" data-toc-modified-id="Функция-для-расчёта-конверсии-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Функция для расчёта конверсии</a></span></li><li><span><a href="#Функция-для-сглаживания-фрейма" data-toc-modified-id="Функция-для-сглаживания-фрейма-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Функция для сглаживания фрейма</a></span></li><li><span><a href="#Функция-для-визуализации-удержания" data-toc-modified-id="Функция-для-визуализации-удержания-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Функция для визуализации удержания</a></span></li><li><span><a href="#Функция-для-визуализации-конверсии" data-toc-modified-id="Функция-для-визуализации-конверсии-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Функция для визуализации конверсии</a></span></li><li><span><a href="#Функция-для-визуализации-LTV-и-ROI" data-toc-modified-id="Функция-для-визуализации-LTV-и-ROI-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Функция для визуализации LTV и ROI</a></span></li></ul></li><li><span><a href="#Проведите-исследовательский-анализ-данных" data-toc-modified-id="Проведите-исследовательский-анализ-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Проведите исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Сколько-всего-потратили-денег?" data-toc-modified-id="Сколько-всего-потратили-денег?-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Сколько всего потратили денег?</a></span></li><li><span><a href="#Сколько-всего-потратили-денег-на-каждый-источник?" data-toc-modified-id="Сколько-всего-потратили-денег-на-каждый-источник?-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Сколько всего потратили денег на каждый источник?</a></span></li><li><span><a href="#Сколько-в-среднем-стоило-привлечение-одного-покупателя-из-каждого-источника?" data-toc-modified-id="Сколько-в-среднем-стоило-привлечение-одного-покупателя-из-каждого-источника?-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Сколько в среднем стоило привлечение одного покупателя из каждого источника?</a></span></li><li><span><a href="#Проанализируйте-общую-окупаемость-рекламы" data-toc-modified-id="Проанализируйте-общую-окупаемость-рекламы-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Проанализируйте общую окупаемость рекламы</a></span></li><li><span><a href="#Проанализируйте-окупаемость-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Проанализируйте-окупаемость-рекламы-с-разбивкой-по-устройствам-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Проанализируйте окупаемость рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Проанализируйте-окупаемость-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Проанализируйте-окупаемость-рекламы-с-разбивкой-по-странам-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Проанализируйте окупаемость рекламы с разбивкой по странам</a></span></li><li><span><a href="#Проанализируйте-окупаемость-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Проанализируйте-окупаемость-рекламы-с-разбивкой-по-рекламным-каналам-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам</a></span></li><li><span><a href="#Анализ-конверсии-и-удержания-с-разбивкой-по-устройствам" data-toc-modified-id="Анализ-конверсии-и-удержания-с-разбивкой-по-устройствам-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Анализ конверсии и удержания с разбивкой по устройствам</a></span></li><li><span><a href="#Анализ-конверсии-и-удержания-с-разбивкой-по-странам" data-toc-modified-id="Анализ-конверсии-и-удержания-с-разбивкой-по-странам-5.9"><span class="toc-item-num">5.9&nbsp;&nbsp;</span>Анализ конверсии и удержания с разбивкой по странам</a></span></li><li><span><a href="#Анализ-конверсии-и-удержания-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Анализ-конверсии-и-удержания-с-разбивкой-по-рекламным-каналам-5.10"><span class="toc-item-num">5.10&nbsp;&nbsp;</span>Анализ конверсии и удержания с разбивкой по рекламным каналам</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Импорт данных

# %%
# импорт библиотек
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt

# %%
# чтение файлов с данными и сохранение их в переменные visits, orders, costs
visits = pd.read_csv(r'\unit_economy\visits_info_short.csv')
orders = pd.read_csv(r'\unit_economy\orders_info_short.csv')
costs = pd.read_csv(r'\unit_economy\costs_info_short.csv')

# %% [markdown]
# ## Изучение общей информации

# %% [markdown]
# ### Изучим таблицу `visits`.
#
# Выведем первые 10 строк, а также общую информацию:

# %%
visits.head(10)
# Out:
#         User Id         Region   Device         Channel        Session Start  \
# 0  981449118918  United States   iPhone         organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone         organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac         organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android          TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac         organic  2019-05-01 03:33:35
# 5   90242400005  United States   iPhone  RocketSuperAds  2019-05-01 07:14:52
# 6   43958116050  United States  Android         organic  2019-05-01 09:03:21
# 7  185365244969  United States   iPhone         organic  2019-05-01 09:37:03
# 8  446013509831  United States   iPhone  RocketSuperAds  2019-05-01 10:26:00
# 9  100970711362  United States      Mac          TipTop  2019-05-01 04:39:53
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# ...

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
# User Id          309901 non-null int64
# Region           309901 non-null object
# Device           309901 non-null object
# Channel          309901 non-null object
# Session Start    309901 non-null object
# Session End      309901 non-null object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %% [markdown]
# В таблице `visits` 6 столбцов:
#
# * `User Id` - уникальный идентификатор пользователя (тип данных - **int64**);
# * `Region` - страна пользователя (тип данных - **object**);
# * `Device` - тип устройства пользователя (тип данных - **object**);
# * `Channel` - идентификатор источника перехода (тип данных - **object**);
# * `Session Start` - дата и время начала сессии (тип данных - **object**);
# * `Session End` - дата и время окончания сессии (тип данных - **object**).
#
# Сразу бросается в глаза нарушение стиля в заголовках: строчные буквы сочетаются с прописными.
#
# Количество значений в столбцах одинаковое, значит в данных нет пропущенных значений.
#
# Также неверен тип данных в столбцах с датой начала и окончания сессии - **object**.

# %% [markdown]
# ### Изучим таблицу `orders`.
#
# Выведем первые 10 строк, а также общую информацию:

# %%
orders.head(10)
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
# 5  129100331057  2019-05-01 01:56:28     4.99
# 6  626807144131  2019-05-01 02:39:21     4.99
# 7  914062168985  2019-05-01 02:02:18     4.99
# 8  769669137453  2019-05-01 03:39:47     4.99
# 9  434198630691  2019-05-01 18:16:50     5.99

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
# User Id     40212 non-null int64
# Event Dt    40212 non-null object
# Revenue     40212 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %% [markdown]
# В таблице `orders` 3 столбца:
#
# * `User Id` - уникальный идентификатор пользователя (тип данных - **int64**);
# * `Event Dt` - дата и время покупки (тип данных - **object**);
# * `Revenue` - сумма заказа (тип данных - **float64**).
#
# В данной таблице так же присутствует нарушение стиля в заголовках - сочетание строчных и прописных букв. Столбец `Event Dt` имеет неправильный тип. Одинаковое количество записей в столбцах свидетельствует о том, что пропуски отсутствуют.

# %% [markdown]
# ### Изучим таблицу `costs`.
#
# Выведем первые 10 строк, а также общую информацию:

# %%
costs.head(10)
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1
# 5  2019-05-06  FaceBoom  118.8
# 6  2019-05-07  FaceBoom  101.2
# 7  2019-05-08  FaceBoom  100.1
# 8  2019-05-09  FaceBoom   93.5
# 9  2019-05-10  FaceBoom  104.5

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
# dt         1800 non-null object
# Channel    1800 non-null object
# costs      1800 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# В таблице `costs` 3 столбца:
#
# * `dt` - дата проведения рекламной кампани (тип данных - **object**);
# * `Channel` - идентификатор рекламного источника (тип данных - **object**);
# * `costs` - расходы на эту кампанию (тип данных - **float64**).
#
# И в таблице `costs` есть нарушение стиля заголовков, выражающееся в смешении строчных и прописных букв. Пропуски отсутствуют. Тип данных в столбце `dt` не верен.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Стиль заголовков

# %% [markdown]
# Выведем на экран названия столбцов таблиц `visits`, `orders`, `costs`:

# %%
# названия колонок таблицы visits
visits.columns
# Out:
# Index(['User Id', 'Region', 'Device', 'Channel', 'Session Start',
#        'Session End'],
#       dtype='object')

# %%
# названия колонок таблицы orders
orders.columns
# Out:
# Index(['User Id', 'Event Dt', 'Revenue'], dtype='object')

# %%
# названия колонок таблицы costs
costs.columns
# Out:
# Index(['dt', 'Channel', 'costs'], dtype='object')

# %% [markdown]
# Сделаем все символы строчными. Для этого переименуем колонки следующим образом:
#
# 1. Таблица `visits`:
# * `'User Id'` → `'user_id'`;
# * `'Region'` → `'region'`;
# * `'Device'` → `'device'`;
# * `'Channel'` → `'channel'`;
# * `'Session Start'` → `'session_start'`;
# * `'Session End'` → `'session_end'`.
#
# 2. Таблица `orders`:
# * `'User Id'` → `'user_id'`;
# * `'Event Dt'` → `'event_dt'`:
# * `'Revenue'` → `'revenue'`.
#
# 3. Таблица `costs`:
# * `'Channel'` → `'channel'`.
#
# Для этого создадим функцию, которая приведет верхний регистр к нижнемук, а также заменит пробелы на `_`:

# %%
def column_rename(data):
    data.columns = [x.lower().replace(' ', '_') for x in data.columns.values]

# %%
# исправляем стиль заголовков таблицы visits
column_rename(visits)

# исправляем стиль заголовков таблицы orders
column_rename(orders)

# исправляем стиль заголовков таблицы costs
column_rename(costs)

# %% [markdown]
# Проверим реультат:

# %%
# заголовки столбцов таблицы visits
visits.columns
# Out:
# Index(['user_id', 'region', 'device', 'channel', 'session_start',
#        'session_end'],
#       dtype='object')

# %%
# заголовки столбцов таблицы orders
orders.columns
# Out:
# Index(['user_id', 'event_dt', 'revenue'], dtype='object')

# %%
# заголовки столбцов таблицы costs
costs.columns
# Out:
# Index(['dt', 'channel', 'costs'], dtype='object')

# %% [markdown]
# Замена отработала корректно.

# %% [markdown]
# ### Изменение типов данных

# %% [markdown]
# Ранее было замечено, что поля, содержащие даты в таблицах `visits`, `orders`, `costs`, имеют тип данных **object**. Преобразуем данные о времени:

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date
# проверим, отработала ли замена
print('VISITS')
print('Тип данных столбца session_start:', visits['session_start'].dtypes)
print('Тип данных столбца session_end:', visits['session_end'].dtypes)
print(50*'-')
print('ORDERS')
print('Тип данных столбца event_dt:', orders['event_dt'].dtypes)
print(50*'-')
print('COSTS')
print('Тип данных столбца dt:', costs['dt'].dtypes)
# Out:
# VISITS
# Тип данных столбца session_start: datetime64[ns]
# Тип данных столбца session_end: datetime64[ns]
# --------------------------------------------------
# ORDERS
# Тип данных столбца event_dt: datetime64[ns]
# --------------------------------------------------
# COSTS
# Тип данных столбца dt: object

# %% [markdown]
# Тип данных успешно изменен.

# %% [markdown]
# ### Дубликаты

# %% [markdown]
# Спевра проверим, нет ли в таблицах неявных дубликатов:

# %%
#просмотр уникальных значений в столбцах region, device, channel таблицы visits
columns = ['region', 'device', 'channel']
for column in columns:
    print(30*'-')
    print(column)
    print(visits[column].unique())
# Out:
# ------------------------------
# region
# ['United States' 'UK' 'France' 'Germany']
# ------------------------------
# device
# ['iPhone' 'Mac' 'Android' 'PC']
# ------------------------------
# channel
# ['organic' 'TipTop' 'RocketSuperAds' 'YRabbit' 'FaceBoom' 'MediaTornado'
#  'AdNonSense' 'LeapBob' 'WahooNetBanner' 'OppleCreativeMedia'
#  'lambdaMediaAds']

# %% [markdown]
# Альтернативные и ошибочные написания значений одного и того же столбца в таблице `visits` не найдены.
#
# Проделаем то же самое с таблицей `costs`:

# %%
#просмотр уникальных значений в столбцах region, device, channel таблицы visits
columns = ['channel']
for column in columns:
    print(30*'-')
    print(column)
    print(costs[column].unique())
# Out:
# ------------------------------
# channel
# ['FaceBoom' 'MediaTornado' 'RocketSuperAds' 'TipTop' 'YRabbit'
#  'AdNonSense' 'LeapBob' 'OppleCreativeMedia' 'WahooNetBanner'
#  'lambdaMediaAds']

# %% [markdown]
# Альтернативные и ошибочные написания значений одного и того же столбца в таблице `costs` не найдены.

# %% [markdown]
# Теперь займемся поиском явных дубликатов: проверим, есть ли в таблицах `visits`, `orders`, `costs` строки, полностью дублирующие друг друга:

# %%
# таблица visits
visits[visits.duplicated(keep = False)].sort_values(by = list(visits.columns))
# Out:
# Empty DataFrame
# Columns: [user_id, region, device, channel, session_start, session_end]
# Index: []

# %%
# таблица orders
orders[orders.duplicated(keep = False)].sort_values(by = list(orders.columns))
# Out:
# Empty DataFrame
# Columns: [user_id, event_dt, revenue]
# Index: []

# %%
# таблица costs
costs[costs.duplicated(keep = False)].sort_values(by = list(costs.columns))
# Out:
# Empty DataFrame
# Columns: [dt, channel, costs]
# Index: []

# %% [markdown]
# Ни в одной из таблиц информация не задвоилась.
#
# Проверять дубликаты по полю `user_id` бессмысленно: уникальный идентификатор пользователя может повторяться много раз, что будет свидетельствовать о разных сессиях, которым свойственны разное время, источники перехода, а возможно и типы устройств пользователя. Попробуем отсортировать таблицу `visits` по полю `user_id`:

# %%
visits.sort_values(by='user_id').head()
# Out:
#        user_id         region   device   channel       session_start  \
# 7045    599326  United States      Mac  FaceBoom 2019-05-09 07:33:16
# 6247    599326  United States  Android  FaceBoom 2019-05-08 06:00:42
# 5537    599326  United States      Mac  FaceBoom 2019-05-07 20:58:57
# 70796  4919697  United States   iPhone  FaceBoom 2019-07-09 12:46:07
# 71604  4919697  United States   iPhone  FaceBoom 2019-07-10 22:27:24
#
#               session_end
# 7045  2019-05-09 08:40:06
# 6247  2019-05-08 06:52:28
# 5537  2019-05-07 21:11:36
# 70796 2019-07-09 14:44:32
# 71604 2019-07-10 23:00:37

# %% [markdown]
# Действительно, за изучаемый период пользователем с уникальным идентификатором 599326 было совершено 3 сессии: 7, 8, 9 мая. Более того, пользователь использовал разные девайсы: Mac и Android.
#
# **ВЫВОД**
#
# Предобработка обнаружила две проблемы:
#
# * нарушения в стиле заголовков;
# * неверный тип данных.
#
# Заголовки были исправлены, тип данных приведен в соответствие.
#
# Теперь можно переходить к дальнейшему анализу.

# %% [markdown]
# ## Задайте функции для расчета и анализа LTV, ROI, удержания и конверсии

# %% [markdown]
# Зададим функции для расчета LTV, ROI, удержания и конверсии, с которыми ранее познакомились в теоретических уроках, - `get_profiles()`, `get_retention()`, `get_conversion()` и `get_ltv()`.

# %% [markdown]
# ### Функция для создания пользовательских профилей

# %%
def get_profiles(sessions, orders, ad_costs, event_names=[]):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ### Функция для расчёта LTV и ROI

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Функция для расчёта удержания

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчёта конверсии

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# Также добавим функции для визуализации определенных шагом ранее метрик - `filter_data()`, `plot_retention()`, `plot_conversion()`, `plot_ltv_roi()`.

# %% [markdown]
# ### Функция для сглаживания фрейма

# %%
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Функция для визуализации удержания

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации конверсии

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации LTV и ROI

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Проведите исследовательский анализ данных

# %% [markdown]
# Получим профили пользователей. Для этого вызовем функцию `get_profiles()`, передав ей данные о посещениях, покупках и тратах на рекламу Procrastinate Pro+.

# %%
# получаем профили пользователей
profiles = get_profiles(visits, orders, costs)
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %% [markdown]
# Определим минимальную и максимальную дату привлечения пользователей:

# %%
print('Минимальная дата привлечения пользователей: ', profiles['dt'].min())
print('Максимальная дата привлечения пользователей: ', profiles['dt'].max())
# Out:
# Минимальная дата привлечения пользователей:  2019-05-01
# Максимальная дата привлечения пользователей:  2019-10-27

# %% [markdown]
# Выясним:
#
# * Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?
# * Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?
# * По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?

# %%
columns = ['region', 'device', 'channel']
for column in columns:
    display(profiles.groupby(column)
          .agg({'user_id': 'nunique', 
                'payer': 'mean'})
          .round(3)
          .sort_values(by='payer', ascending=False))
    print('------------------------------------')
# Out:
#                user_id  payer
# region
# United States   100002  0.069
# Germany          14981  0.041
# UK               17575  0.040
# France           17450  0.038
# ------------------------------------
#          user_id  payer
# device
# Mac        30042  0.064
# iPhone     54479  0.062
# Android    35032  0.059
# PC         30455  0.050
# ------------------------------------
#                     user_id  payer
# channel
# FaceBoom              29144  0.122
# AdNonSense             3880  0.113
# lambdaMediaAds         2149  0.105
# TipTop                19561  0.096
# RocketSuperAds         4448  0.079
# WahooNetBanner         8553  0.053
# YRabbit                4312  0.038
# MediaTornado           4364  0.036
# LeapBob                8553  0.031
# OppleCreativeMedia     8605  0.027
# organic               56439  0.021
# ------------------------------------

# %% [markdown]
# Изучив полученные данные, можно сделать следующие выводы:
#
# 1. Пользователи приходят в приложение из следующих стран: США, Германия, Великобритания, Франция. Больше всего платящих пользователей приходится на США.
# 2. Клиенты пользуются такими устройствами как Mac, iPhone, Android, PC. Платящие пользователи предпочитают Mac и iPhone.
# 3. Рекламные источники привлечения - FaceBoom, AdNonSense, lambdaMediaAds, TipTop, RocketSuperAds, WahooNetBanner, YRabbit, MediaTornado, LeapBob, OppleCreativeMedia, organic. Топ-3 канала, из которых пришло больше всего платящих пользователей - FaceBoom, AdNonSense, lambdaMediaAds.

# %% [markdown]
# # Шаг 4. Маркетинг
#
#
# ### Сколько всего потратили денег?

# %%
# потратили всего
print('Общая сумма расходов на маркетинг составила:', profiles['acquisition_cost'].sum().round(2), '$')
# Out:
# Общая сумма расходов на маркетинг составила: 105497.3 $

# %% [markdown]
# Посмотримс, как изменялись общие расходы на маркетинг во времени:

# %%
# потратили всего на рекламу в разбивке по датам
(profiles
 .groupby('dt')
 .agg({'acquisition_cost': 'sum'})
 .sort_values(by='dt', ascending=False))
# Out:
#             acquisition_cost
# dt
# 2019-10-27           967.165
# 2019-10-26           952.370
# 2019-10-25           862.600
# 2019-10-24           737.590
# 2019-10-23           592.995
# ...                      ...
# 2019-05-05           319.905
# 2019-05-04           337.000
# 2019-05-03           263.070
# 2019-05-02           230.845
# 2019-05-01           304.820
#
# [180 rows x 1 columns]

# %% [markdown]
# Видно, что в начале анализируемого периода (01-05-2019) затраты на рекламу были в 3 раза меньше, нежели в конце (27-10-2019). Визуализируем полученную информацию, чтобы иметь перед глазами полную картину:

# %%
# потратили всего на рекламу в разбивке по датам, визуализация
profiles.pivot_table(
    index = 'dt', values = 'acquisition_cost', aggfunc = 'sum').plot(figsize = (15, 5))
plt.title ('Общие траты на маркетинг')
plt.xlabel('Дата привлечения')
plt.ylabel('CAC, $');
# Out:
# Text(0, 0.5, 'CAC, $')

# %% [markdown]
# Действительно, со временем требовалось все больше и больше денег на рекламу. Посмотрим, как обстоят дела с тратами в каждом рекламном источнике.

# %% [markdown]
# ### Сколько всего потратили денег на каждый источник?

# %%
# траты в разбивке по каналам
(profiles
 .groupby('channel')
 .agg({'acquisition_cost': 'sum'})
 .sort_values(by='acquisition_cost', ascending=False))
# Out:
#                     acquisition_cost
# channel
# TipTop                      54751.30
# FaceBoom                    32445.60
# WahooNetBanner               5151.00
# AdNonSense                   3911.25
# OppleCreativeMedia           2151.25
# RocketSuperAds               1833.00
# LeapBob                      1797.60
# lambdaMediaAds               1557.60
# MediaTornado                  954.48
# YRabbit                       944.22
# organic                         0.00

# %% [markdown]
# Больше всего денег было вложено в каналы под названием **TipTop** и **FaceBoom**. Логично, что затраты на привлечение органических пользователей равны 0. Посмотрим на динамику изменения трат в каждом источнике во времени:

# %%
# динамика изменения трат на маркетинг на каждый источник во времени
profiles.pivot_table(
    index = 'dt', columns = 'channel', values = 'acquisition_cost', aggfunc = 'sum').plot(figsize = (15, 5))
plt.title ('Изменение трат на маркетинг в разбивке по источникам')
plt.xlabel('Дата привлечения')
plt.ylabel('CAC, $');
# Out:
# Text(0, 0.5, 'CAC, $')

# %% [markdown]
# График получился очень шумным. Попробуем взять по оси абсцисс не даты привлечения пользователей, а месяцы:

# %%
# динамика изменения трат на маркетинг на каждый источник во времени
profiles.pivot_table(
    index = 'month', columns = 'channel', values = 'acquisition_cost', aggfunc = 'sum').plot(figsize = (15, 5))
plt.title ('Изменение трат на маркетинг в разбивке по источникам')
plt.xlabel('Месяц привлечения')
plt.ylabel('CAC, $');
# Out:
# Text(0, 0.5, 'CAC, $')

# %% [markdown]
# На графике видно, что два рекламных источника выбиваются из общего числа. Расходы на привлечение пользователей посредством этих двух рекламных источников во многом превосходят остальные. Отсюда возникает вопрос. А окупились ли такие большие расходы? Это будет выяснено в дальнейшем. Попробуем исключить их из графика, чтобы посмотреть на остальные:

# %%
# динамика изменения трат на маркетинг на каждый источник во времени (без TipTop и FaceBoom)
profiles.query('channel != "TipTop" and channel != "FaceBoom"').pivot_table(
    index = 'month', columns = 'channel', values = 'acquisition_cost', aggfunc = 'sum').plot(figsize = (15, 5))
plt.title ('Изменение трат на маркетинг в разбивке по источникам (без TipTop и FaceBoom)')
plt.xlabel('Месяц привлечения')
plt.ylabel('CAC, $');
# Out:
# Text(0, 0.5, 'CAC, $')

# %% [markdown]
# По остальным рекламным каналам все стабильно.

# %% [markdown]
# ### Сколько в среднем стоило привлечение одного покупателя из каждого источника?

# %% [markdown]
# Так как на привлечение органических пользователей никаких трат не было, исключим их из дальнейшего анализа:

# %%
profiles = profiles.query('channel != "organic"')

# %% [markdown]
# Рассчитаем средний САС на одного пользователя для всего проекта:

# %%
print('В среднем на привлечение одного пользователя потребовалось:', profiles['acquisition_cost'].mean().round(3), '$')
# Out:
# В среднем на привлечение одного пользователя потребовалось: 1.127 $

# %% [markdown]
# Теперь узаем, во сколько в среднем обошлось привлечение одного пользователя из каждого источника. Для этого рассчитаем САС по каждому источнику трафика:

# %%
# средний сас на одного пользователя для каждого источника трафика
cac = (profiles
       .groupby('channel')
       .agg({'acquisition_cost': 'mean'})
       .round(2)
       .rename(columns={'acquisition_cost': 'cac'})
       .sort_values(by='cac', ascending=False))
cac
# Out:
#                      cac
# channel
# TipTop              2.80
# FaceBoom            1.11
# AdNonSense          1.01
# lambdaMediaAds      0.72
# WahooNetBanner      0.60
# RocketSuperAds      0.41
# OppleCreativeMedia  0.25
# MediaTornado        0.22
# YRabbit             0.22
# LeapBob             0.21

# %% [markdown]
# Посмотрим, как средний САС для каждого источника изменялся в динамике:

# %%
# динамика изменения среднего САС на каждый источник во времени
profiles.pivot_table(
    index = 'month', columns = 'channel', values = 'acquisition_cost', aggfunc = 'mean').plot(figsize = (15, 5))
plt.title ('Динамика изменения среднего САС в разбивке по источникам во времени')
plt.xlabel('Месяц привлечения')
plt.ylabel('средний CAC, $');
# Out:
# Text(0, 0.5, 'средний CAC, $')

# %% [markdown]
# Дороже всего стоило привлечение одного пользователя из источника **TipTop**. Что примечательно, по сравнению со всеми остальными источниками, только у него средняя стоимость привлечения одного пользователя с каждым месяцем увеличивается. Отбросим его, чтобы посмотреть на динамику остальных источников:

# %%
profiles.query('channel != "TipTop"').pivot_table(
    index = 'month', columns = 'channel', values = 'acquisition_cost', aggfunc = 'mean').plot(figsize = (15, 5))
plt.title ('Динамика изменения среднего САС в разбивке по источникам во времени (без TipTop)')
plt.xlabel('Месяц привлечения')
plt.ylabel('средний CAC, $');
# Out:
# Text(0, 0.5, 'средний CAC, $')

# %% [markdown]
# На графике видно, что у большинства источников средний САС +- стабилен на протяжении всего анализируемого периода времени.  Исключение составляет источник RocketSuperAds, у которого к октябрю стоимость привлечения одного клиента снижается.

# %% [markdown]
# # Шаг 5. Оцените окупаемость рекламы для привлечения пользователей

# %% [markdown]
# Согласно условию задачи, на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. В соответствии с этим установим момент и горизонт анализа данных.

# %%
observation_date = datetime(2019, 11, 1).date()  # момент анализа
horizon_days = 14  # горизонт анализа

# %% [markdown]
# ### Проанализируйте общую окупаемость рекламы

# %% [markdown]
# Сперва оценим общую ситуацию - посмотрим на окупаемость рекламы. Рассчитаем и визуализируем LTV и ROI, вызвав функции `get_ltv()` и `plot_ltv_roi()`.

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# По графикам можно сделать следующие выводы:
#
# * Реклама не окупается. ROI на 14 день - чуть выше 80%.
# * CAC не стабален, он растет. Возможно причина отсутствия окупаемости в этом.
# * LTV подвержен сезонному фактору. Однако этот показатель достаточно стабилен. Значит, дело не в ухудшении качества пользователей.
#
# Чтобы разобраться в причинах, пройдем по всем доступным характеристикам пользователей - стране, источнику и устройству первого посещения.

# %% [markdown]
# ### Проанализируйте окупаемость рекламы с разбивкой по устройствам

# %% [markdown]
# Начнем с разбивки по устройствам: передадим параметру `dimensions` столбец `device`.

# %%
# смотрим окупаемость с разбивкой по устройствам

dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Что говорят графики:
#
# * Реклама окупается только у пользоваталей PC.
# * Стоимость привлечения пользователей всех устройств растет. Больше всего она среди пользователей Mac и IPhone. Что касается пользоваталей РС, то тут САС относительно стабилен и ниже относительно других устройств.
# * LTV подвержен сезонности, но он стабилен.

# %% [markdown]
# ### Проанализируйте окупаемость рекламы с разбивкой по странам

# %% [markdown]
# Передадим параметру `dimensions` столбец `region`.

# %%
# смотрим окупаемость с разбивкой по странам

dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Что говорят графики:
#
# * Реклама не окупается только в США.
# * Стоимость привлечения пользователей из США увеличивается, она в разы больше САС других стран, в которых данный показатель стабилен.
# * LTV все так же подвержен сезонности. В США один пользователь в среднем приносит больше всего денег. Однако видимо этого не достаточно, чтобы окупить траты.

# %% [markdown]
# ### Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам

# %% [markdown]
# Передадим параметру `dimensions` столбец `channel`.

# %%
# смотрим окупаемость с разбивкой по источникам привлечения

dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Что говорят графики:
#
# * Стабильное качетсво привлеченных пользователей. Стоимость привлечения для всех пользователей за исключением канала TipTop стабильна. В TipTop она стремительно растет.
# * Не окупаются пользователи, привлеченные посредством TipTop, FaceBoom, AdNonSense. Стоит заметить, что стоимость привлечения пользователей в данных каналах выше остальных.

# %% [markdown]
# ### Анализ конверсии и удержания с разбивкой по устройствам

# %% [markdown]
# Посчитаем и визуализируем конверсию, вызвав функции `get_conversion()` и `plot_conversion()`.

# %%
# смотрим конверсию с разбивкой по устройствам

dimensions = ['device']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Ранее было отмечено, что окупаются только пользователи PC.
#
# На графиках отчетливо видно, что пользователи остальных устройств очень хорошо конвертируются, даже лучше тех, кто окупается. Проверим удержание.

# %%
# смотрим удержание с разбивкой по устройствам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# И здесь все хорошо. Пользователи всех устройств одинаково удерживаются, нет выбивающихся. Значит дело не в устройствах пользователей.

# %% [markdown]
# ### Анализ конверсии и удержания с разбивкой по странам

# %% [markdown]
# Посчитаем и визуализируем конверсию, вызвав функции `get_conversion()` и `plot_conversion()`.

# %%
# смотрим конверсию с разбивкой по странам

dimensions = ['region']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Ранее было отмечено, что реклама не окупается только в США.
#
# Однако на графиках четко видно, что пользователи из США великолепно конвертируются. Даже лучше пользователей других стран.
#
# Здесь дело точно не в конверсии. Проверим удержание.

# %%
# смотрим удержание с разбивкой по странам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# А вот на данных графиках видно, что платящие пользователи из США стабильно плохо удерживаются.

# %% [markdown]
# ### Анализ конверсии и удержания с разбивкой по рекламным каналам

# %% [markdown]
# Посчитаем и визуализируем конверсию, вызвав функции `get_conversion()` и `plot_conversion()`.

# %%
# смотрим конверсию с разбивкой по рекламным каналам

dimensions = ['channel']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Ранее было отмечено, что пользователи, привлеченные посредством TipTop, FaceBoom, AdNonSense, не окупаются. Однако на графиках видно, что данные каналы конвертируются стабильно хорошо и находятся в числе лидирующих по данному показателю. Посмотрим на удержание.

# %%
# смотрим удержание с разбивкой по рекламным каналам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Графики показывают, что платящие пользователи, привлеченные из AdNonSense и FaceBoom стабильно плохо удерживаются. Что касается TipTop. Скорее всего проблема в цене привлечения, она слишком высокая.
#
# **ЧТО МЫ ИМЕЕМ НА ДАННЫЙ МОМЕНТ:**
#
# * В целом реклама не окупается.
# * Снижать окупаемость рекламы могут пользователи из США, а так же люди, привлеченные из AdNonSense и FaceBoom.
# * Пользователи из разных стран, имеющие разные устройства и рекламные каналы, хорошо конвертируются, здесь вопросов нет.
# * Пользователи из США, а также пользователи, привлеченные из AdNonSense и FaceBoom, стабильно плохо удерживаются. Это может являться ключевой проблемой окупаемости.
#
# Проверим, насколько два этих факта взаимосвязаны. Изучим ситуацию с США. Отфильтруем имеющиеся данные по этой стране, построим небольшой отчет по конкретно каналам, действующим в США, затем оценим для них конверсию и удержание (также построим ROI, LTV, CAC).

# %% [markdown]
# # Ситуация с США

# %% [markdown]
# Отфильтруем данные по стране, сохранив результат в новую переменную `profiles_usa`.

# %%
profiles_usa = profiles.query('region == "United States"') # делаем срез по стране

# %% [markdown]
# Посмотрим, посредством каких рекламных каналов привлекаются пользователи из США.

# %%
(profiles_usa.groupby('channel')
 .agg({'user_id': 'nunique', 
       'payer': 'mean'})
 .round(3)
 .sort_values(by='payer', ascending=False))
# Out:
#                 user_id  payer
# channel
# FaceBoom          29144  0.122
# TipTop            19561  0.096
# RocketSuperAds     4448  0.079
# YRabbit            4312  0.038
# MediaTornado       4364  0.036

# %% [markdown]
# Больше всего платящих пользователей из США в приложение Procrastinate Pro+ было привлечено посредством FaceBoom и TipTop. Плохо удерживающегося рекламного канала AdNonSense в США нет.
#
# Посмотрим, как распределены траты по рекламным каналам в США.

# %%
# траты в разбивке по каналам
(profiles_usa
 .groupby('channel')
 .agg({'acquisition_cost': 'sum'})
 .sort_values(by='acquisition_cost', ascending=False))
# Out:
#                 acquisition_cost
# channel
# TipTop                  54751.30
# FaceBoom                32445.60
# RocketSuperAds           1833.00
# MediaTornado              954.48
# YRabbit                   944.22

# %% [markdown]
# Плохоудерживающийся FaceBoom на втором месте. В него вкладывают львиную долю денег.
#
# Построим и изучим графики конверсии и удержания пользователей из США с разбивкой по рекламным каналам.
#
# Посчитаем и визуализируем конверсию, вызвав функции `get_conversion()` и `plot_conversion()`.

# %%
# смотрим конверсию с разбивкой по рекламным каналам

dimensions = ['channel']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles_usa, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# FaceBoom конвертируется хорошо. Скорее всего дело в удержании.

# %%
# смотрим удержание с разбивкой по рекламным каналам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles_usa, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Вот и разгадка! Пользователи из США, привлеченные посредством рекламного канала FaceBoom, очень плохо удерживаются. В совокупности с большими тратами, совершаемыми для привлечения пользователей, данный факт является следствием убытков, которые терпит компания.

# %% [markdown]
# # Шаг 6. Напишите выводы
#
# Что мы имеет по итогу:
#
# * Основная проблема, связанная с отсутствием окупаемости приложения, сосредоточена в США. На привлечение пользоваталей через рекламный канал FaceBoom выделяются большие средства, однако такие платящие пользователи имеют очень низкое удержание. Можно сделать вывод, что с данного канала приходит нецелевая аудитория. Предложение - не покупать там рекламу.
# * Проблема удержания всех пользователей, привлеченных из TipTop, связана со стабильным повышением стоимости рекламы. Возможно надо пересмотреть подход к покупке рекламы в данном источнике, может и не нужно тратить столько денег на привлечение пользователей?

# %% [markdown]
# **Что можно посоветовать отделу маркетинга?**
#
# 1) Выше был отмечен ряд проблем, которые мешают окупаемости приложения в целом. В связи с этим я бы порекомендовала:
# * не покупать рекламу через канал FaceBoom, поскольку в нем сосредоточена аудитория, которая судя по всему не попадает под профиль типичных пользователей приложения;
# * попробовать снизить затраты на приобретение рекламы в канале TipTop: у пользователей на данной платформе нет проблем ни с конверсией, ни с удержанием. Вполне возможно, если сократить объемы покупаемой рекламы, то вопрос с окупаемостью решится;
# * AdNonSense - рекламный канал, который в отличие от двух пердыдущих отсутствует в США. Стоимость привлечения одного пользователя в этом канале достаточно высока: по величине идет сразу после FaceBoom и TipTop. Пользователи, привлеченные из этого канала хорошо конвертируются, однако совершенно не удерживаются. Рекомендация - попробовать разобраться в проблеме плохого удержания, прежде чем уйти от покупки рекламы в данном канале.
#
# 2) Но не будем зацикливаться только на плохом. Есть альтернативные регионы и каналы. Они показывают хорошие результаты, и возможно стоит задуматься об увеличении затрат на рекламу с целью привлечь еще больше пользователей. Так, среди каналов, пользователи которых показывают и хорошую конверсию, и, что не маловажно, отличаются хорошим удержанием, можно отметить следующие:
# * LambdaMediaAds;
# * RocketSuperAds;
# * WahooNetBanner.
#
# Стоит уделить внимание развитию данных каналов.
