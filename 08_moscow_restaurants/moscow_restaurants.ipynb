# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Импорт-данных" data-toc-modified-id="Импорт-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Импорт данных</a></span></li><li><span><a href="#Изучение-общей-информации" data-toc-modified-id="Изучение-общей-информации-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Изучение общей информации</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Однообразное-написание-названий-заведений" data-toc-modified-id="Однообразное-написание-названий-заведений-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Однообразное написание названий заведений</a></span></li><li><span><a href="#Сеть---не-сеть?" data-toc-modified-id="Сеть---не-сеть?-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Сеть - не сеть?</a></span></li><li><span><a href="#Старбакс-==-Starbucks?" data-toc-modified-id="Старбакс-==-Starbucks?-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Старбакс == Starbucks?</a></span></li><li><span><a href="#Безымянные-заведения" data-toc-modified-id="Безымянные-заведения-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Безымянные заведения</a></span></li><li><span><a href="#Дубликаты" data-toc-modified-id="Дубликаты-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Дубликаты</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Соотношение-видов-объектов-общественного-питания-по-количеству" data-toc-modified-id="Соотношение-видов-объектов-общественного-питания-по-количеству-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Соотношение видов объектов общественного питания по количеству</a></span></li><li><span><a href="#Соотношение-сетевых-и-несетевых-заведений-по-количеству" data-toc-modified-id="Соотношение-сетевых-и-несетевых-заведений-по-количеству-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Соотношение сетевых и несетевых заведений по количеству</a></span></li><li><span><a href="#✔-Комментарий-ревьюера-V.2" data-toc-modified-id="✔-Комментарий-ревьюера-V.2-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>✔ Комментарий ревьюера V.2</a></span></li><li><span><a href="#👀-Комментарий-ревьюера" data-toc-modified-id="👀-Комментарий-ревьюера-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>👀 Комментарий ревьюера</a></span></li><li><span><a href="#Что-характерно-для-сетевых-заведений:-много-заведений-с-небольшим-числом-посадочных-мест-в-каждом-или-мало-заведений-с-большим-количеством-посадочных-мест?" data-toc-modified-id="Что-характерно-для-сетевых-заведений:-много-заведений-с-небольшим-числом-посадочных-мест-в-каждом-или-мало-заведений-с-большим-количеством-посадочных-мест?-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Что характерно для сетевых заведений: много заведений с небольшим числом посадочных мест в каждом или мало заведений с большим количеством посадочных мест?</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#Среднее-количество-посадочных-мест-для-каждого-вида-объекта-общественного-питания" data-toc-modified-id="Среднее-количество-посадочных-мест-для-каждого-вида-объекта-общественного-питания-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Среднее количество посадочных мест для каждого вида объекта общественного питания</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#Информация-об-улице" data-toc-modified-id="Информация-об-улице-4.9"><span class="toc-item-num">4.9&nbsp;&nbsp;</span>Информация об улице</a></span></li><li><span><a href="#!!-Комментарий-ревьюера" data-toc-modified-id="!!-Комментарий-ревьюера-4.10"><span class="toc-item-num">4.10&nbsp;&nbsp;</span>!! Комментарий ревьюера</a></span></li><li><span><a href="#Топ-10-улиц-по-количеству-объектов-общественного-питания" data-toc-modified-id="Топ-10-улиц-по-количеству-объектов-общественного-питания-4.11"><span class="toc-item-num">4.11&nbsp;&nbsp;</span>Топ-10 улиц по количеству объектов общественного питания</a></span></li><li><span><a href="#!!-Комментарий-ревьюера" data-toc-modified-id="!!-Комментарий-ревьюера-4.12"><span class="toc-item-num">4.12&nbsp;&nbsp;</span>!! Комментарий ревьюера</a></span></li><li><span><a href="#✔-Комментарий-ревьюера-V.2" data-toc-modified-id="✔-Комментарий-ревьюера-V.2-4.13"><span class="toc-item-num">4.13&nbsp;&nbsp;</span>✔ Комментарий ревьюера V.2</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-4.14"><span class="toc-item-num">4.14&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#Число-улиц-с-одним-объектом-общественного-питания" data-toc-modified-id="Число-улиц-с-одним-объектом-общественного-питания-4.15"><span class="toc-item-num">4.15&nbsp;&nbsp;</span>Число улиц с одним объектом общественного питания</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-4.16"><span class="toc-item-num">4.16&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#Распределение-количества-посадочных-мест-для-улиц-с-большим-количеством-объектов-общественного-питания" data-toc-modified-id="Распределение-количества-посадочных-мест-для-улиц-с-большим-количеством-объектов-общественного-питания-4.17"><span class="toc-item-num">4.17&nbsp;&nbsp;</span>Распределение количества посадочных мест для улиц с большим количеством объектов общественного питания</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-4.18"><span class="toc-item-num">4.18&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span><ul class="toc-item"><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li></ul></li><li><span><a href="#Презентация" data-toc-modified-id="Презентация-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Презентация</a></span><ul class="toc-item"><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Рынок заведений общественного питания Москвы

# %% [markdown]
# Вы решили открыть небольшое кафе в Москве. Оно оригинальное — гостей должны обслуживать роботы. Проект многообещающий, но дорогой. Вместе с партнёрами вы решились обратиться к инвесторам. Их интересует текущее положение дел на рынке — сможете ли вы снискать популярность на долгое время, когда все зеваки насмотрятся на роботов-официантов?

# %% [markdown]
# ## Импорт данных

# %%
# импорт библиотек
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from plotly.offline import iplot
import numpy as np
from io import BytesIO
import requests

# отключим предупреждения на тот случай, если вдруг они появятся
import warnings
warnings.filterwarnings('ignore')

# %%
# чтение файла с данными и сохранение в переменную rest_data
rest_data = pd.read_csv(r'08_moscow_restaurants\moscow_restaurants.csv')

# встраиваем сторонний файл с улицами Москвы
spreadsheet_id = '1tFq1GmDzupeP4KsyCMu60u72tAwY1uQKOka9T1KEDfs'
file_name = 'https://docs.google.com/spreadsheets/d/{}/export?format=csv'.format(spreadsheet_id)
r = requests.get(file_name)
streets = pd.read_csv(BytesIO(r.content))

# %% [markdown]
# ## Изучение общей информации

# %% [markdown]
# Выведем первые 10 строк таблицы `rest_data`, а также общую информацию:

# %%
rest_data.head(10)
# Out:
#        id               object_name chain object_type  \
# 0  151635                   СМЕТАНА   нет        кафе
# 1   77874                    Родник   нет        кафе
# 2   24309           Кафе «Академия»   нет        кафе
# 3   21894                ПИЦЦЕТОРИЯ    да        кафе
# 4  119365    Кафе «Вишневая метель»   нет        кафе
# 5   27429  СТОЛ. ПРИ ГОУ СОШ № 1051   нет    столовая
# 6  148815                  Брусника    да        кафе
# 7   20957               Буфет МТУСИ   нет    столовая
# 8   20958               КПФ СЕМЬЯ-1   нет    столовая
# 9   28858            Столовая МТУСИ   нет    столовая
#
#                                              address  number
# 0         город Москва, улица Егора Абакумова, дом 9      48
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35
# 2          город Москва, Абельмановская улица, дом 6      95
# 3            город Москва, Абрамцевская улица, дом 1      40
# 4  город Москва, Абрамцевская улица, дом 9, корпус 1      50
# ...

# %%
rest_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15366 entries, 0 to 15365
# Data columns (total 6 columns):
# id             15366 non-null int64
# object_name    15366 non-null object
# chain          15366 non-null object
# object_type    15366 non-null object
# address        15366 non-null object
# number         15366 non-null int64
# dtypes: int64(2), object(4)
# memory usage: 720.4+ KB

# %% [markdown]
# В таблице `rest_data` 6 столбцов:
# * `id` - идентификатор объекта (тип данных - **int64**);
# * `object_name` - название объекта общественного питания (тип данных - **object**);
# * `chain` - сетевой ресторан (тип данных - **object**);
# * `object_type` - тип объекта общественного питания (тип данных - **object**);
# * `address` - адрес (тип данных - **object**);
# * `number` - количество посадочных мест (тип данных - **int64**).
#
# Количество значений в столбцах одинаковое, значит в данных нет пропущенных значений.
#
# На первый взгляд проблем в данных нет. Проверим наличие дубликатов.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Так как данных слишком много, определим основные шаги, которые реализуем посредством предобработки:
# 1. Приведем все названия к однообразному способу написания: заменим прописные буквы строчными, уберем всевозмодные приписки по типу "кафе", ресторан", а также кавычки, тире. Возможно таким образом получится избежать дальнейшего задублирования на каком-нибудь графике одного и того же заведения, которое было записано по-разному.
# 2. Проверим, есть ли такие заведения, которые обозначены как сеть, однако в Москве представлено только одно.
# 3. Проверим, есть ли случаи, когда одно и то же заведение будет записано одновременно на двух языках. Если такие есть, исправим.
# 4. Проверим, есть ли в датафрейме бзымянные заведения. Посмотрим, сколько их. Если их доля несущественна - удалим.
# 5. Проверим, есть ли дубликаты.

# %% [markdown]
# ### Однообразное написание названий заведений

# %%
# выведем первые 10 строк таблицы rest_data
rest_data.head(10)
# Out:
#        id               object_name chain object_type  \
# 0  151635                   СМЕТАНА   нет        кафе
# 1   77874                    Родник   нет        кафе
# 2   24309           Кафе «Академия»   нет        кафе
# 3   21894                ПИЦЦЕТОРИЯ    да        кафе
# 4  119365    Кафе «Вишневая метель»   нет        кафе
# 5   27429  СТОЛ. ПРИ ГОУ СОШ № 1051   нет    столовая
# 6  148815                  Брусника    да        кафе
# 7   20957               Буфет МТУСИ   нет    столовая
# 8   20958               КПФ СЕМЬЯ-1   нет    столовая
# 9   28858            Столовая МТУСИ   нет    столовая
#
#                                              address  number
# 0         город Москва, улица Егора Абакумова, дом 9      48
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35
# 2          город Москва, Абельмановская улица, дом 6      95
# 3            город Москва, Абрамцевская улица, дом 1      40
# 4  город Москва, Абрамцевская улица, дом 9, корпус 1      50
# ...

# %%
# заменим регистр в столбце object_name
rest_data['object_name'] = rest_data['object_name'].str.lower()

# выведем первые 10 строк таблицы rest_data
rest_data.head(10)
# Out:
#        id               object_name chain object_type  \
# 0  151635                   сметана   нет        кафе
# 1   77874                    родник   нет        кафе
# 2   24309           кафе «академия»   нет        кафе
# 3   21894                пиццетория    да        кафе
# 4  119365    кафе «вишневая метель»   нет        кафе
# 5   27429  стол. при гоу сош № 1051   нет    столовая
# 6  148815                  брусника    да        кафе
# 7   20957               буфет мтуси   нет    столовая
# 8   20958               кпф семья-1   нет    столовая
# 9   28858            столовая мтуси   нет    столовая
#
#                                              address  number
# 0         город Москва, улица Егора Абакумова, дом 9      48
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35
# 2          город Москва, Абельмановская улица, дом 6      95
# 3            город Москва, Абрамцевская улица, дом 1      40
# 4  город Москва, Абрамцевская улица, дом 9, корпус 1      50
# ...

# %% [markdown]
# Удалим всевозможные приписки в виде "кафе", "столовая", "ресторан" и т.п., а также кавычки:

# %%
names = ['кафе', 'кофейня', 'закусочная', 'предприятие', 'обслуживания', 'быстрого', 'питания', 'ресторан', 'столовая', 'бар', '«', '»', '-' ]
for name in names:
    rest_data['object_name'] = rest_data['object_name'].str.replace(name, '')
rest_data.head(10)
# Out:
#        id               object_name chain object_type  \
# 0  151635                   сметана   нет        кафе
# 1   77874                    родник   нет        кафе
# 2   24309                  академия   нет        кафе
# 3   21894                пиццетория    да        кафе
# 4  119365           вишневая метель   нет        кафе
# 5   27429  стол. при гоу сош № 1051   нет    столовая
# 6  148815                  брусника    да        кафе
# 7   20957               буфет мтуси   нет    столовая
# 8   20958                кпф семья1   нет    столовая
# 9   28858                     мтуси   нет    столовая
#
#                                              address  number
# 0         город Москва, улица Егора Абакумова, дом 9      48
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35
# 2          город Москва, Абельмановская улица, дом 6      95
# 3            город Москва, Абрамцевская улица, дом 1      40
# 4  город Москва, Абрамцевская улица, дом 9, корпус 1      50
# ...

# %% [markdown]
# ### Сеть - не сеть?

# %% [markdown]
# Попробуем отыскать заведения, которые бы соответствовали одновременно следующим условиям:
# 1. В столбце `chain` напротив заведения указано `да`.
# 2. Выбранное заведение встречается в Москве только один раз.
#
# В найденных заведениях заменим признак принадлежности к сети.

# %%
# ищем не сети
false_chains = (rest_data.query('chain=="да"')
                .groupby('object_name')
                .agg({'object_type': 'count'})
                .query('object_type == 1')
                .reset_index())
# менем столбец chain
rest_data.loc[rest_data['object_name'].isin(false_chains['object_name']), 'chain'] = 'нет'

# %% [markdown]
# ### Старбакс == Starbucks?

# %% [markdown]
# В глаза бросаются наименования объектов, которые наверняка являются одним и тем же заведением. Переименуем их, чтобы избавиться от задвоения:
# * `starbucks coffee`, `starbucks, старбакс кофе`, `starbucks кофе`, `старбакс`, `старбакс кофе`, `кофемания starbucks` → **starbucks**;
# * `van wok ванвок`, `vanwok ванвок` → **vanwok**;
# * `кулинарное бюро kitchen`, `кулинарное бюро китчен` → **kitchen**;
# * `американ сити пицца`, `американ сити пицца цех по изготовлению пиццы` → **американ сити пицца**;
# * `папа джонс пицца`, `пицерия папа джонс` → **папа джонс**;
# * `стейк хаус гудман`, `стейкхаус гудман` → **гудман**.

# %%
synonyms = {'starbucks': ['starbucks coffee', 'starbucks кофе', 'старбакс', 'старбакс кофе', 'starbucks, старбакс кофе', 'starbucks старбакс', 'кофемания starbucks'],
           'vanwok': ['van wok ванвок', 'vanwok ванвок'],
           'kitchen': ['кулинарное бюро китчен', 'кулинарное бюро kitchen'],
           'американ сити пицца': ['американ сити пицца цех по изготовлению пиццы'],
           'папа джонс': ['папа джонс пицца', 'пицерия папа джонс'],
           'гудман': ['стейк хаус гудман', 'стейкхаус гудман']
           }
def check_synonymus(cell):
    for name, syn in synonyms.items():
        if cell in syn: return name
    return cell
rest_data['object_name_new'] = rest_data['object_name'].apply(check_synonymus)

# проверка
rest_data[['object_name', 'object_name_new']].query('object_name_new =="гудман"')
# Out:
#              object_name object_name_new
# 595    стейк хаус гудман          гудман
# 6847    стейкхаус гудман          гудман
# 8289              гудман          гудман
# 8329              гудман          гудман
# 13344             гудман          гудман
# 13345             гудман          гудман

# %% [markdown]
# Замена отработала корректно.

# %%
# удалим столбец object_name
rest_data = rest_data.drop(columns=['object_name'])

# переименуем созданный столбец
rest_data = rest_data.rename(columns={'object_name_new': 'object_name'})

# упорядочим столбцы в нужном нам порядке
rest_data = rest_data[['id', 'object_name', 'chain', 'object_type', 'address', 'number']]
rest_data.head()
# Out:
#        id       object_name chain object_type  \
# 0  151635           сметана   нет        кафе
# 1   77874            родник   нет        кафе
# 2   24309          академия   нет        кафе
# 3   21894        пиццетория    да        кафе
# 4  119365   вишневая метель   нет        кафе
#
#                                              address  number
# 0         город Москва, улица Егора Абакумова, дом 9      48
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35
# 2          город Москва, Абельмановская улица, дом 6      95
# 3            город Москва, Абрамцевская улица, дом 1      40
# 4  город Москва, Абрамцевская улица, дом 9, корпус 1      50

# %% [markdown]
# ### Безымянные заведения

# %% [markdown]
# В исходной таблице могли находиться заведения, у которых нет названия. Это могло быть просто "кафе", "ресторан" и пр. Из-за того, что двумя шагами ранее мы подобные вещи удалили из таблицы, могли образоваться пропуски. Посмотрим, так ли это на самом деле:

# %%
rest_data.query('object_name == ""')
# Out:
#            id object_name chain object_type  \
# 20      21950               нет        кафе
# 61      21214               нет    столовая
# 238     27703               нет    столовая
# 347    130124               нет        кафе
# 372     28431               нет    столовая
# ...       ...         ...   ...         ...
# 15007  219569               нет        кафе
# 15008  219570               нет        кафе
# 15011  206099               нет  закусочная
# 15014  210231               нет        кафе
# 15017  205588               нет   кафетерий
#
#                                                  address  number
# 20               город Москва, Алтайская улица, дом 33/7      30
# 61                 город Москва, Бабаевская улица, дом 3      90
# 238         город Москва, улица Бориса Галушкина, дом 26      45
# 347                  город Москва, улица Дыбенко, дом 44      40
# 372              город Москва, Зубовский бульвар, дом 25      50
# ...

# %% [markdown]
# Действительно, такие строки присутствуют. Заполним их обозначением `no name`:

# %%
def description(object_name):
    if object_name == "":
        return 'no name'
    return object_name
rest_data['object_name'] = rest_data['object_name'].apply(description)

# проверим
rest_data.query('object_name == "no name"')
# Out:
#            id object_name chain object_type  \
# 20      21950     no name   нет        кафе
# 61      21214     no name   нет    столовая
# 238     27703     no name   нет    столовая
# 347    130124     no name   нет        кафе
# 372     28431     no name   нет    столовая
# ...       ...         ...   ...         ...
# 15007  219569     no name   нет        кафе
# 15008  219570     no name   нет        кафе
# 15011  206099     no name   нет  закусочная
# 15014  210231     no name   нет        кафе
# 15017  205588     no name   нет   кафетерий
#
#                                                  address  number
# 20               город Москва, Алтайская улица, дом 33/7      30
# 61                 город Москва, Бабаевская улица, дом 3      90
# 238         город Москва, улица Бориса Галушкина, дом 26      45
# 347                  город Москва, улица Дыбенко, дом 44      40
# 372              город Москва, Зубовский бульвар, дом 25      50
# ...

# %% [markdown]
# ### Дубликаты

# %% [markdown]
# Проверим, есть ли в таблице строки, полностью дублирующие друг друга:

# %%
rest_data[rest_data.duplicated(keep = False)].sort_values(by = list(rest_data.columns))
# Out:
# Empty DataFrame
# Columns: [id, object_name, chain, object_type, address, number]
# Index: []

# %% [markdown]
# Таковые отсутствуют.
#
# Проверим базу на наличие неявных дубликатов:

# %%
# считаем строки до удаления дубликатов
print('Количество строк до удаления дубликатов:', rest_data.shape)

# ищем неявные дубликаты
duplicates = rest_data.duplicated(keep = False, subset=['object_name', 'chain', 'object_type', 'address', 'number'])

# исключаем их из общей таблицы
rest_data = rest_data.loc[~duplicates]    

# считаем строки после удаления дубликатов
print('Количество строк после удаления дубликатов:', rest_data.shape)
# Out:
# Количество строк до удаления дубликатов: (15366, 6)
# Количество строк после удаления дубликатов: (15216, 6)

# %% [markdown]
# Было удалено 156 строк, дублирующихся по полям `object_name`, `chain`, `object_type`, `address`, `number`.

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Соотношение видов объектов общественного питания по количеству

# %%
rest_data.groupby('object_type').agg({'id': 'count'}).sort_values(by='id').plot(kind='barh', legend=False)
plt.suptitle('Соотношение видов объектов общественного питания по количеству')
plt.xlabel('Количество объектов')
plt.ylabel('');

# %% [markdown]
# По данным таблицы `rest_data` в Москве больше всего кафе. Оно и понятно: город располагает к быстрому темпу жизни, где и прием пищи должен быть быстрым, долго в ресторанах не посидишь. На втором, третьем и четвертом месте с небольшим отрывом друг от друга расположились столовые, рестораны и предприятия быстрого обслуживания. Ну а меньше всего в Москве отделов кудинарии в магазнах.

# %% [markdown]
# ### Соотношение сетевых и несетевых заведений по количеству

# %%
report = rest_data.pivot_table(index = 'object_type', columns = 'chain', values = 'id', aggfunc = 'nunique')
report['total'] = report['да']+ report['нет']
report = report.sort_values(by='total')
ax = report[['да', 'нет']].plot(kind='barh', stacked=True)
ax.set_title('Соотношение сетевых и несетевых заведений по количеству')
ax.set_xlabel('Количество объектов')
ax.set_ylabel('');

# %% [markdown]
# На графике видно, что в основном в городе преобладают несетевые заведения.

# %% [markdown]
# Визуально сетевое распределение характерно для предприятий быстрого обслуживания. Для того, чтобы проверить себя, посчитаем, какую долю занимают сетевые заведения в общем количестве объектов для каждого вида:

# %%
report['chain_%'] = round((report['да'] / report['total']) * 100, 2)
report.reset_index()[['object_type', 'chain_%']].sort_values(by='chain_%', ascending=False)
# Out:
# chain                        object_type  chain_%
# 5      предприятие быстрого обслуживания    40.27
# 0              магазин (отдел кулинарии)    26.74
# 8                                   кафе    20.81
# 6                               ресторан    20.36
# 1                             закусочная    13.70
# 2                              кафетерий    11.73
# 4                                    бар     2.46
# 3                                  буфет     1.93
# 7                               столовая     0.12

# %% [markdown]
# Действительно, сетевое распространение характерно для предприятий быстрого обслуживания.

# %% [markdown]
# ### Что характерно для сетевых заведений: много заведений с небольшим числом посадочных мест в каждом или мало заведений с большим количеством посадочных мест?

# %% [markdown]
# Для того, чтобы ответить на этот вопрос необходимо совершить несколько шагов:
# 1. Выбрать все сетевые рестораны.
# 2. Посчитать количество заведений для каждой сети, а также среднее количество посадочных мест для каждой сети.
# 3. Разбить все сети на группы:
# * много заведений - много мест;
# * много заведений - мало мест;
# * мало заведений - много мест;
# * мало заведений - мало мест.
# 4. Построить точечную диаграмму, по которой будет видно преобладание той или иной группы.

# %%
# сколько всего заведений в каждой сети, а также среднее число посадочных мест
chains = (rest_data.query('chain == "да"')
          .groupby('object_name')
          .agg({'id': 'count', 
                'number': 'mean'})
          .round(2)
          .sort_values(by='id', ascending=False).reset_index())
chains.head(10)
# Out:
#        object_name   id  number
# 0      шоколадница  157   57.18
# 1              kfc  155   55.34
# 2       макдоналдс  150   88.34
# 3      бургер кинг  137   46.65
# 4          теремок   94   25.61
# 5   домино'с пицца   90   18.34
# 6  крошка картошка   90   21.86
# 7            милти   72    1.33
# 8         суши wok   72    6.71
# 9        starbucks   51   43.71

# %% [markdown]
# Для того, чтобы разбить все сети на установленные ранее группы, за границу возьмем значение, ниже которого находится четверть данных о количестве заведений / среднем количестве посадочных мест:

# %%
# мало/много заведений в сети
chains['group_rest'] = 'Мало заведений'
chains.loc[chains['id'] > np.percentile(chains['id'], 25), 'group_rest'] = 'Много заведений'

# мало/много посадочных мест
chains['group_seat'] = 'Мало мест'
chains.loc[chains['number'] > np.percentile(chains['number'], 25), 'group_seat'] = 'Много мест'

# объединим столбцы group_rest и group_seat
chains['группа'] = chains['group_rest'].astype(str) + ' - ' + chains['group_seat'].astype(str)

# строим график
plt.figure(figsize=(8, 6))
sns.scatterplot(data = chains, x = 'id', y = 'number', hue = 'группа')
plt.xlabel('Число заведений')
plt.ylabel('Среднее число посадочных мест')
plt.title('Сетевые заведения');

# %% [markdown]
# Из графика следует, что для сетевых заведений характерно мало заведений с большим количеством посадочных мест.

# %% [markdown]
# ### Среднее количество посадочных мест для каждого вида объекта общественного питания

# %% [markdown]
# Сперва посчитаем среднее количество посадочных мест для каждого вида объекта общественного питания:

# %%
report = (rest_data.pivot_table(index = 'object_type', values = 'number', aggfunc = 'mean')
          .round()
          .sort_values(by='number', ascending=False))
report
# Out:
#                                    number
# object_type
# столовая                            130.0
# ресторан                             97.0
# буфет                                52.0
# бар                                  44.0
# кафе                                 40.0
# предприятие быстрого обслуживания    21.0
# кафетерий                             9.0
# закусочная                            8.0
# магазин (отдел кулинарии)             6.0

# %% [markdown]
# Построим несколько графиков: распределение количества посадочных мест в среднем для каждого вида объекта общественного питания и в разбивке по сетевым / несетевым заведениям.

# %%
# количество средних мест для каждого вида объекта общественного питания в целом
report = rest_data.pivot_table(index = 'object_type', values = 'number', aggfunc = 'mean')
report = report.sort_values(by='number')
ax = report.plot(kind='barh', legend=False)
ax.set_title('Среднее количество мест для каждого вида объекта общественного питания')
ax.set_xlabel('Среднее количество посадочных мест')
ax.set_ylabel('');

# %% [markdown]
# Из графика следует, что больше всего в среднем посадочных мест в столовых и ресторанах. Затем с небольшим отрывом друг от друга идут буфеты, бары и кафе. Совсем мало посадочных мет в отделах кулинарии в магазинах.

# %%
# количество средних мест для каждого вида объекта общественного питания в разбивке на сетевые / не сетевые
report = rest_data.pivot_table(index = 'object_type', columns = 'chain', values = 'number', aggfunc = 'mean')
report['total'] = report['да']+ report['нет']
report = report.sort_values(by='total')
ax = report[['да', 'нет']].plot(kind='barh', stacked=True)
ax.set_title('Среднее количество мест для каждого вида объекта общественного питания (сетевые / не сетевые)')
ax.set_xlabel('Среднее количество посадочных мест')
ax.set_ylabel('');

# %% [markdown]
# Что мы видим:
# 1. Больше всего посадочных мест в несетевых столовых и ресторанах.
# 2. Примечательно, что в ресторанах разницы между количеством посадочных мест в сетевом и несетевом типах практически нет.
# 3. Также львиную долю от общего числа посадочных мест в буфетах занимают несетевые заведения.

# %% [markdown]
# ### Информация об улице

# %% [markdown]
# Выделим в отдельный столбец `streetname` информацию об улице из столбца `address`:

# %%
def get_streetname(cell):
    for addr_part in cell.split(','):
        for s_type in ['улица', 'бульвар', 'переулок', 'шоссе', 'проспект',]:
            if s_type in addr_part:
                return addr_part
    return cell.split(',')[1]
rest_data['streetname'] = rest_data['address'].apply(get_streetname)
rest_data['streetname'] = rest_data['streetname'].str.strip()
# посмотрим на результат
rest_data.head(10)
# Out:
#        id               object_name chain object_type  \
# 0  151635                   сметана   нет        кафе
# 1   77874                    родник   нет        кафе
# 2   24309                  академия   нет        кафе
# 3   21894                пиццетория    да        кафе
# 4  119365           вишневая метель   нет        кафе
# 5   27429  стол. при гоу сош № 1051   нет    столовая
# 6  148815                  брусника    да        кафе
# 7   20957               буфет мтуси   нет    столовая
# 8   20958                кпф семья1   нет    столовая
# 9   28858                     мтуси   нет    столовая
#
#                                              address  number  \
# 0         город Москва, улица Егора Абакумова, дом 9      48
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35
# 2          город Москва, Абельмановская улица, дом 6      95
# 3            город Москва, Абрамцевская улица, дом 1      40
# ...

# %% [markdown]
# ### Топ-10 улиц по количеству объектов общественного питания

# %% [markdown]
# Построим график топ-10 улиц по количеству объектов общественного питания:

# %%
street_10 = (rest_data.pivot_table(index = 'streetname', values = 'id', aggfunc = 'count')
             .rename(columns={'id': 'objects_count'})
             .sort_values(by='objects_count', ascending=False)
             .head(10))
ax = street_10.plot(kind='barh', legend=False)
ax.set_title('Топ-10 улиц по количеству объектов общественного питания')
ax.set_xlabel('Количество заведений')
ax.set_ylabel('');

# %% [markdown]
# В выборку попал город Зеленоград. Поскольку мам все равно нет улиц как таковых - в городе экспериментальное деление на микрорайоны, он будет восприниматься как одна улица. В каком-то смысле это может исказить результаты аналиаз. Исключим его:

# %%
street_10 = (rest_data.query('streetname != "город Зеленоград"').pivot_table(index = 'streetname', values = 'id', aggfunc = 'count')
             .rename(columns={'id': 'object_count'})
             .sort_values(by='object_count', ascending=False)
             .head(10))
street_10
# Out:
#                         object_count
# streetname
# проспект Мира                    202
# Профсоюзная улица                181
# Ленинградский проспект           171
# Пресненская набережная           167
# Варшавское шоссе                 165
# Ленинский проспект               148
# проспект Вернадского             126
# Кутузовский проспект             114
# Каширское шоссе                  110
# Кировоградская улица             106

# %% [markdown]
# Ранее нами был встроен сторонний файл с улицами Москвы. Откроем его:

# %%
streets.head()
# Out:
#                         streetname  areaid okrug               area
# 0             Выставочный переулок      17   ЦАО  Пресненский район
# 1                     улица Гашека      17   ЦАО  Пресненский район
# 2          Большая Никитская улица      17   ЦАО  Пресненский район
# 3                Глубокий переулок      17   ЦАО  Пресненский район
# 4  Большой Гнездниковский переулок      17   ЦАО  Пресненский район

# %% [markdown]
# Столбцы `areaid` и `okrug` нам не понадобятся. Отсечем их:

# %%
streets = streets[['streetname', 'area']]

# %% [markdown]
# Для того, чтобы узнать, какому району принадлежат улицы из топ-10, объединим `streets` и `street_10`:

# %%
street_10_area = street_10.merge(streets, on = 'streetname', how = 'left')
street_10_area
# Out:
#                 streetname  object_count                             area
# 0            проспект Мира           202               Алексеевский район
# 1            проспект Мира           202                Ярославский Район
# 2            проспект Мира           202               Район Марьина роща
# 3            проспект Мира           202               Останкинский район
# 4            проспект Мира           202                  Район Ростокино
# 5            проспект Мира           202                   Район Свиблово
# 6            проспект Мира           202                  Мещанский район
# 7        Профсоюзная улица           181              Академический район
# 8        Профсоюзная улица           181                  Район Черемушки
# 9        Профсоюзная улица           181                    Район Ясенево
# 10       Профсоюзная улица           181                   Район Коньково
# 11       Профсоюзная улица           181                Обручевский район
# ...

# %% [markdown]
# Посмотрим, черезчерез сколько районов проходят топ-10 улиц:

# %%
(street_10_area.groupby('streetname')
 .agg({'area': 'count'})
 .reset_index()
 .rename(columns={'area': 'Количество районов', 'streetname': 'Улица'})
 .sort_values(by='Количество районов', ascending=False))
# Out:
#                     Улица  Количество районов
# 0        Варшавское шоссе                   8
# 5      Ленинский проспект                   8
# 9           проспект Мира                   7
# 7       Профсоюзная улица                   6
# 8    проспект Вернадского                   5
# 1         Каширское шоссе                   4
# 4  Ленинградский проспект                   4
# 2    Кировоградская улица                   3
# 3    Кутузовский проспект                   2
# 6  Пресненская набережная                   1

# %% [markdown]
# Варшавской шоссе и Ленинский проспект затрагивают больше всего районов - 8. А вот Пресненская набережная располагается в пределах одного района.

# %% [markdown]
# ### Число улиц с одним объектом общественного питания

# %% [markdown]
# Отберем улицы, на которых располагается лишь одно заведение:

# %%
street_one_object = (rest_data.groupby('streetname')
                     .agg({'object_type': 'count'})
                     .rename(columns={'object_type': 'objects_count'})
                     .query('objects_count == 1'))
street_one_object
# Out:
#                            objects_count
# streetname
# 1-й Балтийский переулок                1
# 1-й Басманный переулок                 1
# 1-й Ботанический проезд                1
# 1-й Вешняковский проезд                1
# 1-й Голутвинский переулок              1
# ...                                  ...
# улица Шумилова                         1
# улица Шумкина                          1
# улица Щорса                            1
# улица Энгельса                         1
# шоссе Фрезер                           1
#
# [575 rows x 1 columns]

# %% [markdown]
# 574 улицы имеют только один объект общественного питания.

# %% [markdown]
# Посмотрим, в каких районах расположены полученные улицы:

# %%
street_one_object_area = street_one_object.merge(streets, on = 'streetname', how = 'left')
street_one_object_area.head(10)
# Out:
#                    streetname  objects_count                  area
# 0     1-й Балтийский переулок              1        Район Аэропорт
# 1      1-й Басманный переулок              1       Басманный район
# 2      1-й Басманный переулок              1  Красносельский район
# 3     1-й Ботанический проезд              1        Район Свиблово
# 4     1-й Вешняковский проезд              1       Рязанский район
# 5   1-й Голутвинский переулок              1        Район Якиманка
# 6       1-й Заречный переулок              1                   NaN
# 7   1-й Зачатьевский переулок              1       Район Хамовники
# 8      1-й Кирпичный переулок              1  Район Соколиная Гора
# 9  1-й Кожевнический переулок              1     Даниловский район

# %% [markdown]
# В 6 строке в столбце `area` имеется пропуск. Не исключено, что он не единственный. Посмотрим, сколько получилось пропусков в таблице `street_one_object_area`:

# %%
print('В столбце area таблицы street_one_object_area содержится:', street_one_object_area['area'].isna().sum(), 'пропуска(ов).')
# Out:
# В столбце area таблицы street_one_object_area содержится: 54 пропуска(ов).

# %% [markdown]
# Заполним пропущенные значения фразой `не определен`:

# %%
street_one_object_area.loc[street_one_object_area['area'].isna(), 'area'] = 'не определен'

# проверим
print('В столбце area таблицы street_one_object_area содержится:', street_one_object_area['area'].isna().sum(), 'пропуска(ов).')
# Out:
# В столбце area таблицы street_one_object_area содержится: 0 пропуска(ов).

# %% [markdown]
# Выведем топ-10 районов, в которых сосредоточены улицы с одним объектом общественного питания:

# %%
(street_one_object_area.groupby('area')
 .agg({'streetname': 'count'})
 .rename(columns={'streetname': 'street_count'})
 .sort_values(by='street_count', ascending=False)
 .head(10))
# Out:
#                     street_count
# area
# не определен                  54
# Таганский район               26
# Район Хамовники               26
# Басманный район               25
# Пресненский район             21
# Тверской район                20
# Район Арбат                   18
# Район Марьина роща            18
# Мещанский район               16
# Район Сокольники              15

# %% [markdown]
# ### Распределение количества посадочных мест для улиц с большим количеством объектов общественного питания

# %% [markdown]
# Используем ранее созданный справочник `street_10`. Сперва на основе таблицы `rest_data` сформируем датафрейм `street_seat_number`, в котором останутся данные только по заведениям, которые располагаются на улицах, содержащихся в `street_10`:

# %%
street_seat_number = rest_data[rest_data['streetname'].isin(street_10.index)]

# %% [markdown]
# Для того, чтобы посмотреть распределение количества посадочных мест для улиц с большим количеством объектов общественного питания, построим boxplot:

# %%
# зададим размер будущему графику
plt.figure(figsize=(8, 7))

# строим boxplot
ax = sns.boxplot(orient = 'h', x = 'number', y = 'streetname', data = street_seat_number)
plt.xlim(0,400)
plt.xlabel('Количество посадочных мест')
plt.ylabel('')
plt.title('Распределение количества посадочных мест для улиц с большим количеством объектов общественного питания');
print('Среднее количество посадочных мест заведений на топ-10 улицах по количеству объектов:', street_seat_number['number'].median())
print(100*'-')
# Out:
# Среднее количество посадочных мест заведений на топ-10 улицах по количеству объектов: 40.0
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# В среднем количество посадочных мест равняется 40, а максимальное количество мест достигает 200. Выбросы скорее всего говорят о том, что на некоторых улицах количество посадочных мест увеличено, что, возможно связано с высокой проходимостью.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Дадим рекомендации о виде заведения, количестве посадочных мест, а также районе расположения.
#
# В ходе анализа мы выяснили, что наибольшее количество объектов общественного питания составляют кафе, столовые, рестораны, предприятия быстрого обслуживания и бары.
#
# В большей мере сетевое распространение характерно для предприятий быстрого обслуживания, в меньшей - для магазинов, ресторанов и кафе. Как правило для сетевого распространения характерно мало заведений с большим количеством посадочных мест.
#
# ***Среднее количество посадочных мест по типам объектов общественного питания:***
# 1. Столовая - 130 шт.
# 2. Ресторан - 97 шт.
# 3. Буфет - 52 шт.
# 4. Бар - 44 шт.
# 5. Кафе - 40 шт.
# 6. Предприятие быстрого обслуживание - 21 шт.
# 7. Кафетерий - 9 шт.
# 8. Закусочная - 8 шт.
# 9. Магазин (отдел кулинарии) - 6 шт.
#
# Наибольшее количество посадочных мест у **столовых**.
#
# ***Топ-10 улиц с наибольшим количеством заведений:***
# 1. проспект Мира - 202 шт.
# 2. Профсоюзная улица - 181 шт.
# 3. Ленинградский проспект - 171 шт.
# 4. Пресненская набережная - 167 шт.
# 5. Варшавское шоссе - 165 шт.
# 6. Ленинский проспект - 148 шт.
# 7. проспект Вернадского - 126 шт.
# 8. Кутузовский проспект - 114 шт.
# 9. Каширское шоссе - 110 шт.
# 10. Кировоградская улица - 106 шт.
#
# ***Среднее количество посадочных мест в заведениях на топ-10 улицах по количеству объектов - 40***.
#
# # Рекомендации
# На основе приведенных выше данных можно можно порекомендовать открыть кафе (можно предположить, что раз их больше, то они и популярнее, хотя не факт) со средним количеством посадочных мест  - 30. Выбирая район и улицу, целесообразнее будет разместить объект на одной из топ-10 улиц.

# %% [markdown]
# ## Презентация

# %% [markdown]
# https://drive.google.com/file/d/14gFF5Cxi1d_3MZ3_-3vAVpIWFv4XirMZ/view?usp=sharing
