# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-общей-информации" data-toc-modified-id="Изучение-общей-информации-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение общей информации</a></span></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Стиль-заголовков" data-toc-modified-id="Стиль-заголовков-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Стиль заголовков</a></span></li><li><span><a href="#Пропуски-значений" data-toc-modified-id="Пропуски-значений-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Пропуски значений</a></span></li><li><span><a href="#Изменение-типов-данных" data-toc-modified-id="Изменение-типов-данных-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Изменение типов данных</a></span></li><li><span><a href="#Дубликаты" data-toc-modified-id="Дубликаты-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Дубликаты</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Cколько-игр-выпускалось-в-разные-годы.-Важны-ли-данные-за-все-периоды?" data-toc-modified-id="Cколько-игр-выпускалось-в-разные-годы.-Важны-ли-данные-за-все-периоды?-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Cколько игр выпускалось в разные годы. Важны ли данные за все периоды?</a></span></li><li><span><a href="#Как-менялись-продажи-по-платформам?-Выберите-платформы-с-наибольшими-суммарными-продажами-и-постройте-распределение-по-годам.-За-какой-характерный-срок-появляются-новые-и-исчезают-старые-платформы?" data-toc-modified-id="Как-менялись-продажи-по-платформам?-Выберите-платформы-с-наибольшими-суммарными-продажами-и-постройте-распределение-по-годам.-За-какой-характерный-срок-появляются-новые-и-исчезают-старые-платформы?-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Как менялись продажи по платформам? Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?</a></span></li><li><span><a href="#Возьмите-данные-за-соответствующий-актуальный-период." data-toc-modified-id="Возьмите-данные-за-соответствующий-актуальный-период.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Возьмите данные за соответствующий актуальный период.</a></span></li><li><span><a href="#Какие-платформы-лидируют-по-продажам,-растут-или-падают?-Выберите-несколько-потенциально-прибыльных-платформ." data-toc-modified-id="Какие-платформы-лидируют-по-продажам,-растут-или-падают?-Выберите-несколько-потенциально-прибыльных-платформ.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.</a></span></li><li><span><a href="#Постройте-график-«ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам.-Опишите-результат." data-toc-modified-id="Постройте-график-«ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам.-Опишите-результат.-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.</a></span></li><li><span><a href="#Постройте-диаграмму-рассеяния-и-посчитайте-корреляцию-между-отзывами-и-продажами.-Сформулируйте-выводы." data-toc-modified-id="Постройте-диаграмму-рассеяния-и-посчитайте-корреляцию-между-отзывами-и-продажами.-Сформулируйте-выводы.-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.</a></span></li><li><span><a href="#Соотнесите-выводы-с-продажами-игр-на-других-платформах." data-toc-modified-id="Соотнесите-выводы-с-продажами-игр-на-других-платформах.-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Соотнесите выводы с продажами игр на других платформах.</a></span></li><li><span><a href="#Посмотрите-на-общее-распределение-игр-по-жанрам.-Что-можно-сказать-о-самых-прибыльных-жанрах?-Выделяются-ли-жанры-с-высокими-и-низкими-продажами?" data-toc-modified-id="Посмотрите-на-общее-распределение-игр-по-жанрам.-Что-можно-сказать-о-самых-прибыльных-жанрах?-Выделяются-ли-жанры-с-высокими-и-низкими-продажами?-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?</a></span></li></ul></li><li><span><a href="#Составление-портрета-пользователя-каждого-региона" data-toc-modified-id="Составление-портрета-пользователя-каждого-региона-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Составление портрета пользователя каждого региона</a></span><ul class="toc-item"><li><span><a href="#Топ-5-популярных-платформ" data-toc-modified-id="Топ-5-популярных-платформ-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Топ-5 популярных платформ</a></span></li><li><span><a href="#Топ-5-популярных-жанров" data-toc-modified-id="Топ-5-популярных-жанров-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Топ-5 популярных жанров</a></span></li><li><span><a href="#Влияет-ли-рейтинг-ESRB-на-продажи-в-отдельном-регионе" data-toc-modified-id="Влияет-ли-рейтинг-ESRB-на-продажи-в-отдельном-регионе-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Влияет ли рейтинг ESRB на продажи в отдельном регионе</a></span></li></ul></li><li><span><a href="#Проверка-гипотез" data-toc-modified-id="Проверка-гипотез-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые" data-toc-modified-id="Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Средние пользовательские рейтинги платформ Xbox One и PC одинаковые</a></span></li><li><span><a href="#Средние-пользовательские-рейтинги-жанров-Action--и-Sports-разные" data-toc-modified-id="Средние-пользовательские-рейтинги-жанров-Action--и-Sports-разные-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Средние пользовательские рейтинги жанров Action  и Sports разные</a></span></li></ul></li><li><span><a href="#Итоги-исследования" data-toc-modified-id="Итоги-исследования-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Итоги исследования</a></span></li></ul></div>

# %% [markdown]
# ## Изучение общей информации

# %%
# импорт библиотек 
import pandas as pd
import numpy as np
from scipy import stats as st
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# чтение файа с данными и сохранение в data
data = pd.read_csv(r'\games\games.csv')

# %% [markdown]
# Изучим таблицу `data`. Первые 10 строк, а также общая информация:

# %%
data.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#    NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     41.36     28.96      3.77         8.45          76.0          8      E
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# Name               16713 non-null object
# Platform           16715 non-null object
# Year_of_Release    16446 non-null float64
# Genre              16713 non-null object
# NA_sales           16715 non-null float64
# EU_sales           16715 non-null float64
# JP_sales           16715 non-null float64
# Other_sales        16715 non-null float64
# Critic_Score       8137 non-null float64
# User_Score         10014 non-null object
# Rating             9949 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# В таблице 11 столбцов:
# * `Name` - название игры (тип данных - **object**);
# * `Platform` - платформа (тип данных - **object**);
# * `Year_of_Release` - год выпуска (тип данных - **float64**);
# * `Genre` - жанр игры (тип данных - **object**);
# * `NA_sales` - продажи в Северной Америке (миллионы проданных копий) (тип данных - **float64**);
# * `EU_sales` - продажи в Европе (миллионы проданных копий) (тип данных - **float64**);
# * `JP_sales` - продажи в Японии (миллионы проданных копий) (тип данных - **float64**);
# * `Other_sales` - продажи в других странах (миллионы проданных копий) (тип данных - **float64**);
# * `Critic_Score` - оценка критиков (максимум 100) (тип данных - **float64**);
# * `User_Score` - оценка пользователей (максимум 10) (тип данных - **object**);
# * `Rating` - рейтинг от организации ESRB (тип данных - **object**).
#
# Сразу бросается в глаза нарушение стиля в заголовках: строчные буквы сочетаются с прописными.
#
# Количество значений в столбцах различается. Значит в данных есть пропущенные значения.

# %% [markdown]
# **ВЫВОД**
#
# В каждой строке таблицы `data` содержатся данные о продажах игр, оценки пользователей и экспертов, жанры и платформы.
#
# Предварительно можно утверждать, что данных достаточно для проверки гипотез. Однако в датасете встречаются пропуски, а в названиях колонок - расхождения с хорошим стилем.
#
# Чтобы двигаться дальше, необходимо устранить проблемы в данных.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Стиль заголовков

# %% [markdown]
# Выведем на экран названия столбцов:

# %%
data.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'NA_sales', 'EU_sales',
#        'JP_sales', 'Other_sales', 'Critic_Score', 'User_Score', 'Rating'],
#       dtype='object')

# %% [markdown]
# Сделаем все символы строчными. Для этого переименуем колонки следующим образом:
#
# * `'Name'` → `'name'`;
# * `'Platform'` → `'platform'`;
# * `'Year_of_Release'` → `'year_of_release'`;
# * `'Genre'` → `'genre'`;
# * `'NA_sales'` → `'na_sales'`;
# * `'EU_sales'` → `'eu_sales'`;
# * `'JP_sales'` → `'jp_sales'`;
# * `'Other_sales'` → `'other_sales'`;
# * `'Critic_Score'` → `'critic_score'`;
# * `'User_Score'` → `'user_score'`;
# * `'Rating'` → `'rating'`.

# %%
# переименование столбцов
data.columns = data.columns.str.lower()

# %% [markdown]
# Проверим результат. Для этого еще раз выведем на экран названия столбцов:

# %%
data.columns
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %% [markdown]
# Столбцы успешно переименованы.

# %% [markdown]
# ### Пропуски значений

# %% [markdown]
# Для поиска пропущенных значений обратимся к методу `isna()`, передав результат его работы методу `mean()`:

# %%
((data.isna().mean()) * 100).sort_values(ascending=False)
# Out:
# critic_score       51.319174
# rating             40.478612
# user_score         40.089740
# year_of_release     1.609333
# genre               0.011965
# name                0.011965
# other_sales         0.000000
# jp_sales            0.000000
# eu_sales            0.000000
# na_sales            0.000000
# platform            0.000000
# dtype: float64

# %% [markdown]
# Итак, мы имеем пропущенные значения в следующих столбцах:
#
# * `critic_score` (оценка критиков) - пропуски в столбцах, содержащих ту или иную оценку не следует заполнять, поскольку любые значения, которые мы подставим в них, исказят результаты корреляционного анализа и стат-тестов.
# * `rating` (рейтинг от организации ESRB) - так как это категориальная переменная, заполним ее заглушкой (используем для этих целей значение **"unknown"**).
# * `user_score` (оценка пользователей) - ситуация аналогична с `critic_score`.
# * `year_of_release` (год выпуска) - пропусков в этом столбце мало, если мы не возьмем их в расчет, врядли упустим что-то важное, поэтому просто удалим их.
# * `genre` (жанр игры) - ситуация аналогична с `year_of_release`.
# * `name` (название игры) - ситуация аналогична с `year_of_release`.
#
# Также по условию необходимо обратить внимание на аббревиатуру `tbd` в столбце `user_score`. Посмотрим, насколько часто оно встречается. Для этого посчитаем количество строк, содержащих эту аббревиатуру:

# %%
data[data['user_score'] == 'tbd'].shape
# Out:
# (2424, 11)

# %% [markdown]
# 2 424 строки.
#
# `tbd` расшифровывается как `'to be defined'` *(предстоит определить)*. Так как оценка пока еще не известна, будет логично заменить `tbd` на **"nan"**.
#
# Сперва вместо пропущенных значений в столбце `rating` подставим строку **"unknown"**:

# %%
data['rating'] = data['rating'].fillna('unknown')

# %% [markdown]
# Теперь заменим `tbd` в столбце `user_score` на  **"nan"**:

# %%
data.loc[data['user_score'] == 'tbd', 'user_score'] = float('nan')

# %% [markdown]
# И в конце отфильтруем строки, содержащие пропуски в столбцах `year_of_release`, `genre`, `name`:

# %%
columns = ['year_of_release', 'genre', 'name']
for column in columns:
    data = data[data[column].isna() == False]

# %% [markdown]
# Убедимся, что в таблице не осталось пропусков, кроме как в столбцах `critic_score` и `user_score`

# %%
data.isna().mean()
# Out:
# name               0.000000
# platform           0.000000
# year_of_release    0.000000
# genre              0.000000
# na_sales           0.000000
# eu_sales           0.000000
# jp_sales           0.000000
# other_sales        0.000000
# critic_score       0.514534
# user_score         0.546157
# rating             0.000000
# dtype: float64

# %%
data.query('platform == "PS2"').isna().sum()
# Out:
# name                 0
# platform             0
# year_of_release      0
# genre                0
# na_sales             0
# eu_sales             0
# jp_sales             0
# other_sales          0
# critic_score       852
# user_score         907
# rating               0
# dtype: int64

# %% [markdown]
# ### Изменение типов данных

# %% [markdown]
# Ранее было замечено, что поле, содержащее информацию о годе выпуска игры, имеет тип данных **float64**. Так как у года нет дробной части, можно смело изменить тип данных с **object** на **int**.
#
# Также данные в столбце `user_score` имеют тип **object**. Так как в дальнейшем они нам пригодятся для анализа (диаграмма рассеяния не построится по **object**), изменим их тип на **float64**.
#
# Осуществим это с помощью `astype()`, после выведем еще раз общую информацию о таблице:

# %%
data['year_of_release'] = data['year_of_release'].astype('int')
data['user_score'] = data['user_score'].astype('float')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16444 entries, 0 to 16714
# Data columns (total 11 columns):
# name               16444 non-null object
# platform           16444 non-null object
# year_of_release    16444 non-null int32
# genre              16444 non-null object
# na_sales           16444 non-null float64
# eu_sales           16444 non-null float64
# jp_sales           16444 non-null float64
# other_sales        16444 non-null float64
# critic_score       7983 non-null float64
# user_score         7463 non-null float64
# rating             16444 non-null object
# dtypes: float64(6), int32(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# Тип данных успешно изменен.

# %% [markdown]
# ### Дубликаты

# %% [markdown]
# Проверим, есть ли в таблице строки, полностью дублирующие друг друга (отдельно дубликаты названий игр искать бессмысленно - их будет много в силу того, что у них могут быть как разные платформы, так и рейтинги):

# %%
data[data.duplicated(keep = False)].sort_values(by = list(data.columns))
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating]
# Index: []

# %% [markdown]
# Посмотрим, есть ли строки, в которых дублировались бы название игры и платформа. Возможно у дублей будут разные продажи, и таблица data дает неверное представление о суммарных продажах.

# %%
data[data[['name', 'platform']].duplicated(keep = False)].sort_values(by = list(data.columns))
# Out:
#                               name platform  year_of_release   genre  \
# 16230                Madden NFL 13      PS3             2012  Sports
# 604                  Madden NFL 13      PS3             2012  Sports
# 5972   Need for Speed: Most Wanted       PC             2005  Racing
# 11715  Need for Speed: Most Wanted       PC             2012  Racing
# 1591   Need for Speed: Most Wanted     X360             2005  Racing
# 1190   Need for Speed: Most Wanted     X360             2012  Racing
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 16230      0.00      0.01      0.00         0.00          83.0         5.5
# 604        2.11      0.22      0.00         0.23          83.0         5.5
# 5972       0.02      0.23      0.00         0.04          82.0         8.5
# 11715      0.00      0.06      0.00         0.02          82.0         8.5
# 1591       1.00      0.13      0.02         0.10          83.0         8.5
# ...

# %% [markdown]
# Что мы видим:
# * `Need for Speed: Most Wanted` - судя по информации в инернете, это правда 2 игры с одинаковым названием, которые вышли в разные годы. Чтобы обозначить это, добавим к названию более поздней игры год - 2012.
# * `Madden NFL 13` - у одной из строк практически нулевые продажи. Просто удалим ее.

# %%
# добавим год к названию игры Need for Speed: Most Wanted
mask = data.query('name == "Need for Speed: Most Wanted" and year_of_release == 2012').index
data.loc[mask, 'name'] = 'Need for Speed: Most Wanted (2012)'

# удалим плохие строки игры Madden NFL 13
data.drop(16230, inplace=True)

# %% [markdown]
# **ВЫВОД**
#
# Предобработка обнаружила три проблемы в данных:
# * нарушения в стиле заголовков;
# * пропущенные значения;
# * значения `tbd` в столбце `user_score`;
# * дублирующиеся значения в некоторых строках.
#
# Заголовки были исправлены, чтобы упростить работу с таблицей.
#
# Пропущенные значения были заменены на **"unknown"**. Некоторые строки, содержащие пропуски, были отброшены.
#
# Игры `Need for Speed: Most Wanted` были разграничены - на ту, которая вышла в 2005, и ту, которая вышла в 2012.
#
# Теперь можно переходить к дальнейшему анализу.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Cколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %% [markdown]
# Посчитаем, сколько игр было выпущено в каждом году. Для этого сгруппируем данные из таблицы `data` по годам, посчитав количество записей в столбце `name`. Результат выведем на экран:

# %%
data.groupby('year_of_release').agg({'name': 'count'})
# Out:
#                  name
# year_of_release
# 1980                9
# 1981               46
# 1982               36
# 1983               17
# 1984               14
# 1985               14
# 1986               21
# 1987               16
# 1988               15
# 1989               17
# 1990               16
# 1991               41
# 1992               43
# 1993               60
# 1994              121
# 1995              219
# 1996              263
# 1997              289
# 1998              379
# 1999              338
# 2000              350
# 2001              482
# 2002              829
# 2003              775
# 2004              762
# 2005              939
# 2006             1006
# 2007             1197
# 2008             1427
# 2009             1426
# 2010             1255
# 2011             1136
# 2012              652
# 2013              544
# 2014              581
# 2015              606
# 2016              502

# %% [markdown]
# Можно заметить, что рывок в релизах игр произошел в 1994 году (по сравнению с предыдущим годом количество выпущенных игр увеличилось вдвое). И с тех пор поддерживается положительная динамика вплоть до 2011 года. После - пошел резкий спад. Для большей наглядности изобразим результат в виде графика:

# %%
data.groupby('year_of_release').agg({'name': 'count'}).plot()
plt.xlabel('Год выпуска')
plt.ylabel('Количество выпущенных игр')
plt.title('Динамика выпуска игр по годам');

# %% [markdown]
# Действительно, с 1980 г. по 1995 г. выпускалось крайне мало игр. Смотря на график, сложно говорить о какой-либо успешности. Однако с 1995 г. данная индустрия начинает набирать обороты. Поэтому, в рамках исследования данные за годы, предшествующие 1995 г., не важны.
#
# Говоря об успешности, мало иметь представление лишь о количестве выпущенных игр. В первую очередь успешность определяется количеством проданных экземпляров. Посмотрим на динамику общих продаж. Для этого сперва посчитаем, сколько всего было продано копий каждой игры в Северной Америке, Европе, Японии и других регионах, сохраним полученный результат в столбце `total_sales`:

# %%
data['total_sales'] = data['na_sales'] + data['jp_sales'] + data['other_sales'] + data['eu_sales']

# %% [markdown]
# Теперь посчитаем сумму проданных экземпляров по каждому году:

# %%
data.groupby('year_of_release').agg({'total_sales': 'sum'}).plot()
plt.xlabel('Год выпуска')
plt.ylabel('Количество проданных игр, млн.')
plt.title('Динамика продаж по годам');

# %% [markdown]
# Новый график также иллюстрирует ситуацию, когда, начиная с 1995 г. продажи компьютерных игр начали резко расти. Все-таки получается, что период с 1980 по 1995 гг. наименее интересный.

# %% [markdown]
# ### Как менялись продажи по платформам? Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?

# %% [markdown]
# Найдем сумму проданных экземпляров по каждой из платформ. Для этого сгруппируем данные из таблицы `data` и суммируем значения из ранее созданного столбца `total_sales`. Результат отсортируем по убыванию значений столбца `total_sales` и сохраним в переменную `platform_sales`:

# %%
platform_sales = data.groupby('platform').agg({'total_sales': 'sum'}).sort_values(by='total_sales').reset_index()
platform_sales
# Out:
#    platform  total_sales
# 0      PCFX         0.03
# 1        GG         0.04
# 2       3DO         0.10
# 3      TG16         0.16
# 4        WS         1.42
# 5        NG         1.44
# 6       SCD         1.86
# 7        DC        15.95
# 8       GEN        28.35
# 9       SAT        33.59
# 10      PSV        53.81
# 11     WiiU        82.19
# 12     2600        86.48
# 13     XOne       159.32
# 14       GC       196.73
# 15     SNES       200.04
# 16      N64       218.01
# 17      NES       251.05
# 18       XB       251.57
# 19       GB       254.43
# 20       PC       255.76
# 21      3DS       257.81
# 22      PSP       289.53
# 23      GBA       312.88
# 24      PS4       314.14
# 25       PS       727.58
# 26       DS       802.78
# 27      Wii       891.18
# 28      PS3       931.33
# 29     X360       961.24
# 30      PS2      1233.56

# %% [markdown]
# Самая продаваемая платформа - PS2. Платформа, не пользующаяся популярностью - PCFX.

# %% [markdown]
# Сохраним в переменной `platform_sales` топ-10 платформ, лидирующиих по продажам:

# %%
platform_sales = platform_sales.tail(10)['platform'].to_list()

# %% [markdown]
# Построим распределение по годам для выбранных платформ за все время:

# %%
data.query('platform in @platform_sales').pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum').plot(figsize=(15,5))
plt.xlabel('Год выпуска')
plt.ylabel('Количество проданных игр, млн.')
plt.title('Динамика продаж по годам в разбивке по платформам');

# %% [markdown]
# Глядя на график навскидку можно сказать, что срок жизни каждой платформы, которая входит в топ-10, равен практически 10 годам.

# %% [markdown]
# ### Возьмите данные за соответствующий актуальный период.

# %% [markdown]
# Для выявления актуального периода не будем ограничиваться лишь платформами, входящими в топ-10, проведем анализ, учитывая все платформы. Сгруппируем данные из таблицы `data` таким образом, чтобы на выходе получить информацию о том, сколько было продано копий игр отдельной платформы за каждый год. Результат сохраним в переменную `actual_period`:

# %%
# установим порог
min_sales = 5

# суммарные продажи выше порога
actual_period = data.groupby(['platform', 'year_of_release']).agg({'total_sales': 'sum'}).query('total_sales > @min_sales')

# %% [markdown]
# Для того, чтобы определить актуальный период, по которому будет проводиться последующий анализ, необходимо рассчитать жизненный период каждой платформы. Для этого посчитаем, сколько лет существовала каждая из них, а после найдем среднее значение:

# %%
actual_period.reset_index().groupby('platform').agg({'year_of_release': 'nunique'}).rename(columns={'year_of_release': 'unique_count'}).mean()
# Out:
# unique_count    6.916667
# dtype: float64

# %% [markdown]
# Получается, что в среднем жизненный цикл платформы составляет 6 лет.
#
# По условию необходимо построить прогноз на 2017 г. Исходя из этого определим актуальным периодом = 2017 - 6. Получается период, берущий начало в 2011 г.

# %% [markdown]
# ### Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.

# %% [markdown]
# Рассмотрим платформы за актуальный период (с 2011 года):

# %%
data.query('year_of_release > 2010').pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')
# Out:
# platform           3DS     DS     PC   PS2     PS3     PS4    PSP    PSV  \
# year_of_release
# 2011             63.20  26.18  35.03  0.45  156.78     NaN  17.82   4.63
# 2012             51.36  11.01  23.22   NaN  107.35     NaN   7.69  16.19
# 2013             56.57   1.54  12.38   NaN  113.25   25.99   3.14  10.59
# 2014             43.76    NaN  13.28   NaN   47.76  100.00   0.24  11.90
# 2015             27.78    NaN   8.52   NaN   16.82  118.90   0.12   6.25
# 2016             15.14    NaN   5.25   NaN    3.60   69.25    NaN   4.25
#
# platform           Wii   WiiU    X360   XOne
# year_of_release
# 2011             59.65    NaN  143.84    NaN
# 2012             21.71  17.56   99.74    NaN
# 2013              8.59  21.65   88.58  18.96
# 2014              3.75  22.03   34.74  54.07
# 2015              1.14  16.35   11.96  60.14
# 2016              0.18   4.60    1.52  26.15

# %% [markdown]
# Глядя на полученную таблицу, можно точно сказать, в каком году закончились продажи каждой платформы. А для платформ PS4, WiiU и XOne - определить год появления. Для наглядности представим информацию в виде графика:

# %%
data.query('year_of_release > 2010').pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum').plot(figsize=(12,5))
plt.xlabel('Год выпуска')
plt.ylabel('Количество проданных игр, млн.')
plt.title('Динамика продаж по годам в разбивке по платформам в актуальном периоде');

# %% [markdown]
# На графике четко видно, что за рассмотренный период времени:
# 1. Лидер продаж - PS3, на втором месте - 3DS, на третьем - PS4;
# 2. По трем платформам прекратились продажи:
#     * PS2 - в 2011 году;
#     * DS - в 2013 году;
#     * PSP - в 2015 году.
#
# Уберем из дальнейшего анализа платформы DS и PSP, данные по ним могут негативно сказаться на дальнейших рекомендациях. Также в дальнейшем анализе будем использовать только актуальный период.

# %%
# перезапишем переменную data в соответствии с новыми условиями
data = data.query('platform != "DS" and platform != "PSP" and platform != "PS2" and year_of_release > 2010')

# %% [markdown]
# Для того, чтобы определить потенциально прибыльные платформы, посмотрим поближе, как обстоят дела на конец 2016 года:

# %%
data.query('year_of_release >= 2015').pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum').plot(figsize=(12,5))
plt.xlabel('Год выпуска')
plt.ylabel('Количество проданных игр, млн.')
plt.title('Динамика продаж по годам в разбивке по платформам (на конец 2016 года)');

# %% [markdown]
# На графике видно, что практически доживает свой срок Wii - у нее на конец 2016 года самые низкие продажи. Безусловные идеры в 2016 году - PS4, XOne, а также 3DS. Примечательно, что XOne не входит в топ-10 платформ, однако характеризуется хорошей динамикой.

# %% [markdown]
# ### Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.

# %% [markdown]
# Построим график «ящик с усами» по глобальным продажам игр в разбивке по платформам:

# %%
data.boxplot(column='total_sales', by='platform')
plt.ylim(0, 1.5)
plt.xlabel('Платформа')
plt.ylabel('Количество проданных экземпляров, млн.')
plt.title('Продажи игр в разбивке по платформам');

# %% [markdown]
# График позволяет увидеть лидеров продаж (X360, WiiU, XOne, PS3, PS4, Wii), а также тех, у кого продажи идут не очень (PSV, PS2). Наличие большого количества выбросов за пределами верхник границ "ящика" говорит о том, что у каждой платформы есть определенный набор бестселлеров.

# %% [markdown]
# ### Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.

# %% [markdown]
# Построим для потенциально прибыльных платформ диаграмму рассеяния, которая покажет зависимость между отзывами пользователей и количеством проданных копий. Рассчитаем коэффициент корреляции Пирсона для каждой из платформ.

# %%
platforms = ['3DS', 'XOne', 'PS4']
for platform in platforms:
    data[data['platform'] == platform].plot(x='user_score', y='total_sales', kind='scatter', alpha=0.3)
    print('Коэффициент корреляции для', platform, ':',  data[data['platform'] == platform]['user_score'].corr(data[data['platform'] == platform]['total_sales']))
    plt.title(platform)
    plt.xlabel('Оценка пользователей')
    plt.ylabel('Продажи')
    plt.ylim(0,20);
# Out:
# Коэффициент корреляции для 3DS : 0.2220784364339088
# Коэффициент корреляции для XOne : -0.06892505328279414
# Коэффициент корреляции для PS4 : -0.03195711020455643

# %% [markdown]
# Судя по диаграммам и коэффициентам корреляции, оценки пользователей и продажи связаны очень слабо. Посмотрим, как обстоят дела у критиков:

# %%
platforms = ['3DS', 'XOne', 'PS4']
for platform in platforms:
    data[data['platform'] == platform].plot(x='critic_score', y='total_sales', kind='scatter', alpha=0.3)
    print('Коэффициент корреляции для', platform, ':',  data[data['platform'] == platform]['critic_score'].corr(data[data['platform'] == platform]['total_sales']))
    plt.suptitle(platform)
    plt.xlabel('Оценка критиков')
    plt.ylabel('Продажи')
    plt.ylim(0,20)
# Out:
# Коэффициент корреляции для 3DS : 0.3487397305984834
# Коэффициент корреляции для XOne : 0.4169983280084017
# Коэффициент корреляции для PS4 : 0.4065679020617816

# %% [markdown]
# Отзывы критиков коррелируют с продажами чуть лучше, чем отзывы пользователей. Однако уровень связи все еще низкий. Посмотрим, зависят ли как-то отзывы пользователей и критиков:

# %%
platforms = ['3DS', 'PS3', 'PS4']
for platform in platforms:
    data[data['platform'] == platform].plot(x='critic_score', y='user_score', kind='scatter', alpha=0.3)
    print('Коэффициент корреляции для', platform, ':',  data[data['platform'] == platform]['critic_score'].corr(data[data['platform'] == platform]['user_score']))
    plt.suptitle(platform)
    plt.xlabel('Оценка критиков')
    plt.ylabel('Оценка пользователей')
    plt.ylim(0,20)
# Out:
# Коэффициент корреляции для 3DS : 0.745222133798423
# Коэффициент корреляции для PS3 : 0.5666701329579801
# Коэффициент корреляции для PS4 : 0.5576539782764632

# %% [markdown]
# Судя по диаграммам и коэффициентам, оценки критиков и пользователей связаны между собой достаточно хорошо.

# %% [markdown]
# ### Соотнесите выводы с продажами игр на других платформах.

# %% [markdown]
# Повторим действия из п. 3.6 для остальных платформ, входящих в актуальный период: **PC**, **PS2**, **PSV**, **Wii**, **X360**, **XOne**.
# Построим диаграмму рассеяния и посчитаем корреляцию между отзывами и продажами для каждой платформы:

# %%
platforms = ['X360', 'Wii', 'XOne', 'WiiU', 'PC', 'PSV']
for platform in platforms:
    data[data['platform'] == platform].plot(x='user_score', y='total_sales', kind='scatter', alpha=0.3)
    print('Коэффициент корреляции для', platform, ':',  data[data['platform'] == platform]['user_score'].corr(data[data['platform'] == platform]['total_sales']))
    plt.suptitle(platform)
    plt.xlabel('Оценка пользователей')
    plt.ylabel('Продажи')
    plt.ylim(0,20);
# Out:
# Коэффициент корреляции для X360 : 0.0389181707291026
# Коэффициент корреляции для Wii : 0.14550376734945006
# Коэффициент корреляции для XOne : -0.06892505328279414
# Коэффициент корреляции для WiiU : 0.4002190202148617
# Коэффициент корреляции для PC : -0.04896683233511955
# Коэффициент корреляции для PSV : 0.01348875683588649

# %% [markdown]
# По сравнению с потенциально прибыльными платформами разницы особой не наблюдается: очень низкая корреляция, практически нулевая. Посмотрим, как обстоят дела у критиков:

# %%
platforms = ['X360', 'Wii', 'XOne', 'WiiU', 'PC', 'PSV']
for platform in platforms:
    data[data['platform'] == platform].plot(x='critic_score', y='total_sales', kind='scatter', alpha=0.3)
    print('Коэффициент корреляции для', platform, ':',  data[data['platform'] == platform]['critic_score'].corr(data[data['platform'] == platform]['total_sales']))
    plt.suptitle(platform)
    plt.xlabel('Оценка критиков')
    plt.ylabel('Продажи')
    plt.ylim(0,20);
# Out:
# Коэффициент корреляции для X360 : 0.39125332454845546
# Коэффициент корреляции для Wii : 0.2922694954272934
# Коэффициент корреляции для XOne : 0.4169983280084017
# Коэффициент корреляции для WiiU : 0.34837976012017496
# Коэффициент корреляции для PC : 0.3141847396903632
# Коэффициент корреляции для PSV : 0.13176292727608932

# %% [markdown]
# По сравнению с потенциально прибыльными корреляция значительно ниже. Посмотрим, зависят ли как-то отзывы пользователей и критиков:

# %%
platforms = ['X360', 'Wii', 'XOne', 'WiiU', 'PC', 'PSV']
for platform in platforms:
    data[data['platform'] == platform].plot(x='critic_score', y='user_score', kind='scatter', alpha=0.3)
    print('Коэффициент корреляции для', platform, ':',  data[data['platform'] == platform]['critic_score'].corr(data[data['platform'] == platform]['user_score']))
    plt.suptitle(platform)
    plt.xlabel('Оценка критиков')
    plt.ylabel('Оценка пользователей')
    plt.ylim(0,20)
# Out:
# Коэффициент корреляции для X360 : 0.5683859265712157
# Коэффициент корреляции для Wii : 0.44447990433534956
# Коэффициент корреляции для XOne : 0.47246211241658054
# Коэффициент корреляции для WiiU : 0.7700795968080212
# Коэффициент корреляции для PC : 0.4648154264295742
# Коэффициент корреляции для PSV : 0.7342995628112938

# %% [markdown]
# Так же как и у потенциально прибыльных платформ наблюдается сильная связь между отзывами критиков и пользователей.

# %% [markdown]
# ### Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %% [markdown]
# Для начала посмотрим, сколько игр было выпущено в каждом жанре:

# %%
data.groupby('genre').agg({'name': 'count'}).plot(kind='bar')
plt.xlabel('Жанры')
plt.ylabel('Количество выпущенных игр')
plt.title('Распределение игр по жанрам');

# %% [markdown]
# Безусловный лидер по количеству выпущенных игр - жанр Action. Примерно на одном уровне стоят Role-Playing, Sports, Shooter, Adventure, Misc, Racing. Меньше всего игр выпущено в жанрах Puzzle, Strategy, Simulation, Fighting и Platform. Посмотрим, как обстоят дела с продажами:

# %%
data.groupby('genre').agg({'total_sales': 'sum'}).plot(kind='bar')
plt.xlabel('Жанры')
plt.ylabel('Количество проданных экземпляров')
plt.title('Распределение продаж по жанрам');

# %% [markdown]
# Самую большую прибыль имеет лидер продаж - Action. Это объясняется большим тиражом. На втором мете жанр Shooter. Среди жанров с маленьким количеством игр из общей картины выбивается Platform. Для относительно маленького количества выпущенных игр заметен большой их тираж. Жанр, являющийся самым нераспространенным, закономерно самый непродаваемый (Puzzle).

# %% [markdown]
# Посчитаем и для наглядности визуализируем медианные продажи игр по жанрам, чтобы определить жанры с высокими и низкими продажами:

# %%
(data
 .groupby('genre')
 .agg({'total_sales': 'median'})
 .rename(columns={'total_sales': 'median_sales'})
 .sort_values(by='median_sales')).plot(kind='bar')
plt.xlabel('Жанры')
plt.ylabel('Медианные продажи')
plt.title('Медианное распределение продаж по жанрам');

# %% [markdown]
# Судя по медианным продажам, безусловным лидером является жанр Shooter. Интересно, что самый продаваемый жанр Action располагается на 8 месте по медианному распределению продаж. Скорее всего это связано с появлением у него каких-то бестселлеров, благодаря которым так взлетели общие продажи. Именно поэтому так важно уделить внимание медианным значениям, поскольку на них не влияют аномально высокие/низкие значения.

# %% [markdown]
# ## Составление портрета пользователя каждого региона

# %% [markdown]
# ### Топ-5 популярных платформ

# %% [markdown]
# Составим рейтинг из топ-5 популярных платформ для каждого из регионов:

# %%
regions_sales = ['na_sales', 'eu_sales', 'jp_sales']
for region in regions_sales:
    sales_data = data.pivot_table(index='platform',  values=region, aggfunc='sum').sort_values(by=region, ascending=False).head()
    sales_data.plot(kind='pie', x='platform', y=region, autopct='%.2f')
    plt.suptitle(region);

# %% [markdown]
# Самая популярная платформа в Северной Америке - X360, доля игр, проданных ддя нее составляет 33.37%. В Европе наибольшей популярностью пользуется PS3 (30.24%), в Японии - 3DS (50.1%). Примечательно, что X360 не входит в топ-5 платформ в Японии. А платформы PSV и WiiU, так популярные в Японии, отсутствуют в Северной Америке и Европе.
#
# Также в Европе хорошо идут продажи PS4 - данная платформа занимает второе место, доля проданных игр - 26.16%.
#
# И в Северной Америке и в Японии практически одинаково пользуется популярностью платформа PS3 - в обоих регионах она занимает второе место по продажам.
#
# В целом рынок популярных платформ в Европе и Северной Америке очень схож, чего не скажешь о Японии - популярные для нее платформы либо вовсе отсутствуют в других регионах, либо занимают одну из последних позиций.

# %% [markdown]
# ### Топ-5 популярных жанров

# %% [markdown]
# Посмотрим, как распределены продажи по жанрам в каждом регионе:

# %%
regions_sales = ['na_sales', 'eu_sales', 'jp_sales']
for region in regions_sales:
    sales_data = data.pivot_table(index='genre',  values=region, aggfunc='sum').sort_values(by=region, ascending=False).head()
    sales_data.plot.pie(x='genre', y=region, autopct='%.2f')
    plt.suptitle(region);

# %% [markdown]
# Ситуация с продажами по жанрам весьма интересная. В Северной Америке и Европе мы можем наблюдать одинаковую картину: самый популярный жанр - Action, сразу за ним идут Shooter, Sports, Misc и Role-Playing.
#
# В Японии же все наоборот. Самый популярный жанр - Role-Playing, уже потом идет Action. Также в топ-5 жанров в этой стране входит Platform, который отсутствует в двух других регионах.

# %% [markdown]
# ### Влияет ли рейтинг ESRB на продажи в отдельном регионе

# %% [markdown]
# Согласно информации из интернета:
# * EC - для детей раннего возраста;
# * E - для всех;
# * E10+ - для всех старше 10 лет;
# * T - для подростков 13-19 лет;
# * M - от 17 лет;
# * AO - только для взрослых.

# %%
regions_sales = ['na_sales', 'eu_sales', 'jp_sales']
for region in regions_sales:
    sales_data = data.pivot_table(index='rating',  values=region, aggfunc='sum').sort_values(by=region, ascending=False)
    sales_data.plot.pie(x='rating', y=region, autopct='%.2f')
    plt.suptitle(region)

# %% [markdown]
# Между рынками есть разница по продажам игр разного возрастного рейтинга. В основном на это влияют разные жанровые предпочтения. Можно сказать, что это созависимые параметры. Например, в Северной Америке и Европе лидирующие жанры скорее соответствуют возрасту пользователей от 17 лет. На диаграммах мы видим подтверждающие эту гипотезу данные - жанр М лидирует по продажам в обоих регионах. Во всех трех регионах второе место занимает рейтинг Е. Оно и понятно: большинство пользователей предпочитают жанр Action< который явно "для всех". Поэтому можно сказать, что рейтинг ESRB не влияет на продажи.

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# ### Средние пользовательские рейтинги платформ Xbox One и PC одинаковые
#
# Сформулируем нулевую и альтернативную гипотезы:
# * **Нулевая гипотеза** - средние пользовательские рейтинги одинаковые;
# * **Альтернативная гипотеза** - средние пользовательские рейтинги различаются.
#
# Для проверки гипотез обратимя к методу `ttest_ind()`. Уровень alpha зададим 0.05.
#
# Метод `ttest_ind()` имеет параметр **equal_var**, который может принимать значения **True** и **False**. Поскольку наша цель - найти различия средний величин, то мы уже заранее предполагаем, что распределения отличаются, а значит и дисперсии отличаются. Получается, что необходимо указывать **equal_var = False**. Однако необходимо проверить, насколько данный ход мыслей верен. Прежде чем расчитать дисперсии, необходимо избавиться от пропущенных значений в столбце **user_score** (оставить их не получится, потому что статтест не отработает, а заменять их на медианные/средние значения не стоит, это может исказить финальную картину):

# %%
# удаляем пропуски в столбце user_score
data_user_score = data[data['user_score'].isna() == False]

# %% [markdown]
# Проверим, все ли удалилось:

# %%
print('Осталось пропущенных значений: ', data_user_score['user_score'].isna().sum())
# Out:
# Осталось пропущенных значений:  0

# %% [markdown]
# Отлично, теперь можно расчитать дисперсии, средние и средние отклонения:

# %%
data_user_score.query('platform == "PC" or platform == "XOne"').pivot_table(index='platform', aggfunc = {'user_score': ['mean', 'std', 'var']})
# Out:
#          user_score
#                mean       std       var
# platform
# PC         6.451792  1.611303  2.596296
# XOne       6.521429  1.380941  1.906997

# %% [markdown]
# Вот все и подтвердилось: дисперсии разные. Присваиваем **False** параметру **equal_var**. Проверим первую гипотезу:

# %%
xb_platform = data_user_score[data_user_score['platform'] == 'XOne']['user_score']
pc_platform = data_user_score[data_user_score['platform'] == 'PC']['user_score']

alpha = .05

result = st.ttest_ind(xb_platform, pc_platform, equal_var=False)

print('p-значение: ', result.pvalue)
if result.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение:  0.6130712247638477
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Результат проведенного теста говорит о том, что средние пользовательские рейтинги не различаются. Основная гипотеза, сформулированная ранее, подтвердилась.

# %% [markdown]
# ### Средние пользовательские рейтинги жанров Action  и Sports разные

# %% [markdown]
# Сформулируем нулевую и альтернативную гипотезу:
# * **Нулевая гипотеза** - средние пользовательские рейтинги жанров Action и Sports одинаковы;
# * **Альтернативная гипотеза** - средние пользовательские рейтинги жанров Action и Sports различаются.

# %% [markdown]
# Будем использовать метод ttest_ind(). Начнем с расчета дисперсий:

# %%
data_user_score.query('genre == "Action" or genre == "Sports"').pivot_table(index='genre', aggfunc = {'user_score': ['mean', 'std', 'var']})
# Out:
#        user_score
#              mean       std       var
# genre
# Action   6.780030  1.340632  1.797295
# Sports   5.659751  1.708142  2.917748

# %% [markdown]
# Дисперсии и средние отличаются. Проведем тест:

# %%
xb_platform = data_user_score[data_user_score['genre'] == 'Action']['user_score']
pc_platform = data_user_score[data_user_score['genre'] == 'Sports']['user_score']

alpha = .05

result = st.ttest_ind(xb_platform, pc_platform, equal_var=False)

print('p-значение: ', result.pvalue)
if result.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение:  3.2930114707043448e-18
# Отвергаем нулевую гипотезу

# %% [markdown]
# Результат теста говорит о том, что средние пользовательские рейтинги жанров Action и Sports разные. Основная гипотеза, сформулированная в начале, подтвердилась.

# %% [markdown]
# ## Итоги исследования

# %% [markdown]
# В ходе исследования проверили две гипотезы:
# 1. Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
#
# Первая гипотеза подтвердилась. Средний пользовательский рейтинг у платформы PC практически такой же, как и у Xbox One.
#
# 2. Средние пользовательские рейтинги жанров Action и Sports разные.
#
# Вторая гипотеза тоже подтвердилась. Средние пользовательские рейтинги этих двух жанров можно считать разными.
#
# Если делать ставки на продвижение одной определенной платформы, то это однозначно должна быть PS4 с жанром игр либо Action, либо Shooter, поскольку они лидируют в выбранных регионах.
